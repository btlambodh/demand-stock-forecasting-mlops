# %% [markdown]
# #  Demand Stock Forecasting MLOps Pipeline
#
# **Author:** Bhupal Lambodhar
# **Email:** btiduwarlambodhar@sandiego.edu
# **Repository:** https://github.com/btlambodh/demand-stock-forecasting-mlops
#
# ---
#
# ##  Overview
#
# This notebook provides an interactive interface to run the complete MLOps pipeline for demand stock forecasting. It replicates all the functionality from the project's Makefile while preserving SageMaker context and providing comprehensive monitoring.
#
# ###  Key Features:
# - **Data Pipeline Management**: Validation, feature engineering, and infrastructure setup
# - **Model Training & Registry**: Automated training with SageMaker Model Registry integration
# - **Deployment Workflows**: Dev, staging, and production deployment automation
# - **Monitoring & Observability**: Real-time performance and drift monitoring
# - **Quality Assurance**: Testing, linting, and security checks
#
# ###  Architecture Components:
# - **AWS Services**: SageMaker, S3, Athena, Feature Store
# - **ML Framework**: Scikit-learn with custom forecasting models
# - **Infrastructure**: Feature Store for ML, Athena for analytics
# - **Monitoring**: Performance tracking and data drift detection
#
# ---

# %% [markdown]
# ##  1. Environment Setup & Configuration
#
# **Purpose**: Initialize the environment, load configurations, and establish AWS connections.
#
# This cell sets up all necessary imports, loads project configuration, and establishes connections to AWS services. It also performs health checks to ensure all dependencies are available.

# %%
import os
import sys
import yaml
import json
import boto3
import pandas as pd
import numpy as np
import subprocess
import time
from datetime import datetime
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Project configuration
PROJECT_ROOT = Path.cwd().parent if 'notebooks' in str(Path.cwd()) else Path.cwd()
CONFIG_PATH = PROJECT_ROOT / 'config.yaml'
SRC_PATH = PROJECT_ROOT / 'src'

# Add source path to Python path
sys.path.insert(0, str(SRC_PATH))

print(f" Project Root: {PROJECT_ROOT}")
print(f" Source Path: {SRC_PATH}")
print(f" Config Path: {CONFIG_PATH}")

# Load configuration
try:
    with open(CONFIG_PATH, 'r') as f:
        config = yaml.safe_load(f)
    print(" Configuration loaded successfully")
    
    # Display key configuration
    aws_region = config['aws']['region']
    s3_bucket = config['aws']['s3']['bucket_name']
    print(f" AWS Region: {aws_region}")
    print(f" S3 Bucket: {s3_bucket}")
    
except FileNotFoundError:
    print(" Config file not found. Please ensure config.yaml exists in the project root.")
    raise

# Initialize AWS clients
try:
    s3_client = boto3.client('s3', region_name=aws_region)
    sagemaker_client = boto3.client('sagemaker', region_name=aws_region)
    athena_client = boto3.client('athena', region_name=aws_region)
    
    # Test AWS connectivity
    s3_client.list_objects_v2(Bucket=s3_bucket, MaxKeys=1)
    sagemaker_client.list_endpoints(MaxResults=1)
    athena_client.list_work_groups()
    
    print(" AWS services connected successfully")
    print("   • S3 access confirmed")
    print("   • SageMaker access confirmed")
    print("   • Athena access confirmed")
    
except Exception as e:
    print(f" AWS connection failed: {e}")
    print("Please check your AWS credentials and permissions.")
# Out:
#  Project Root: /home/sagemaker-user/demand-stock-forecasting-mlops
#  Source Path: /home/sagemaker-user/demand-stock-forecasting-mlops/src
#  Config Path: /home/sagemaker-user/demand-stock-forecasting-mlops/config.yaml
#  Configuration loaded successfully
#  AWS Region: us-east-1
#  S3 Bucket: sagemaker-us-east-1-346761359662
#  AWS connection failed: An error occurred (AccessDeniedException) when calling the ListWorkGroups operation: User: arn:aws:sts::346761359662:assumed-role/AmazonSageMaker-ExecutionRole-20250511T063988/SageMaker is not authorized to perform: athena:ListWorkGroups because no identity-based policy allows the athena:ListWorkGroups action
# Please check your AWS credentials and permissions.

# %% [markdown]
# ##  2. Project Status & Health Check
#
# **Purpose**: Display current project status and perform comprehensive health checks.
#
# This cell provides an overview of the current project state, including git status, data availability, model files, and system resources. It helps identify any issues before running pipelines.

# %%
def run_health_check():
    """Comprehensive system health check"""
    print(" SYSTEM HEALTH CHECK")
    print("=" * 50)
    
    # Python environment
    print(f" Python Version: {sys.version.split()[0]}")
    print(f" Virtual Environment: {os.environ.get('CONDA_DEFAULT_ENV', 'Not detected')}")
    
    # Git status
    try:
        git_branch = subprocess.check_output(['git', 'branch', '--show-current'], 
                                           cwd=PROJECT_ROOT, text=True).strip()
        print(f" Git Branch: {git_branch}")
        
        git_status = subprocess.check_output(['git', 'status', '--porcelain'], 
                                           cwd=PROJECT_ROOT, text=True)
        if git_status.strip():
            print(" Git Status: Uncommitted changes detected")
        else:
            print(" Git Status: Clean working directory")
    except:
        print(" Git Status: Not a git repository or git not available")
    
    # Directory structure
    data_path = PROJECT_ROOT / 'data'
    models_path = PROJECT_ROOT / 'models'
    
    print(f"\n DIRECTORY STATUS:")
    print(f"   Data directory: {'✅' if data_path.exists() else '❌'} {data_path}")
    print(f"   Models directory: {'✅' if models_path.exists() else '❌'} {models_path}")
    
    if data_path.exists():
        data_files = list(data_path.rglob('*.csv')) + list(data_path.rglob('*.parquet'))
        print(f"   Data files found: {len(data_files)}")
    
    if models_path.exists():
        model_files = list(models_path.rglob('*.pkl')) + list(models_path.rglob('*.joblib'))
        print(f"   Model files found: {len(model_files)}")
    
    # System resources
    try:
        import psutil
        cpu_percent = psutil.cpu_percent(interval=1)
        memory_percent = psutil.virtual_memory().percent
        disk_percent = psutil.disk_usage('/').percent
        
        print(f"\n SYSTEM RESOURCES:")
        print(f"   CPU Usage: {cpu_percent:.1f}%")
        print(f"   Memory Usage: {memory_percent:.1f}%")
        print(f"   Disk Usage: {disk_percent:.1f}%")
    except ImportError:
        print("\n System resource monitoring not available (psutil not installed)")
    
    # Dependency check
    print(f"\n DEPENDENCIES:")
    dependencies = [
        ('pandas', 'import pandas'),
        ('numpy', 'import numpy'),
        ('scikit-learn', 'import sklearn'),
        ('boto3', 'import boto3'),
        ('yaml', 'import yaml')
    ]
    
    for name, import_stmt in dependencies:
        try:
            exec(import_stmt)
            print(f"   ✅ {name}")
        except ImportError:
            print(f"   ❌ {name} - Missing")
    
    print("\n" + "=" * 50)
    print(" Health check completed!")

# Run health check
run_health_check()
# Out:
#  SYSTEM HEALTH CHECK
# ==================================================
#  Python Version: 3.12.9
#  Virtual Environment: base
#  Git Branch: main
#  Git Status: Uncommitted changes detected
#
#  DIRECTORY STATUS:
#    Data directory: ✅ /home/sagemaker-user/demand-stock-forecasting-mlops/data
#    Models directory: ✅ /home/sagemaker-user/demand-stock-forecasting-mlops/models
#    Data files found: 8
#    Model files found: 6
#
#  SYSTEM RESOURCES:
#    CPU Usage: 0.1%
#    Memory Usage: 1.6%
#    Disk Usage: 0.0%
#
#  DEPENDENCIES:
#    ✅ pandas
#    ✅ numpy
#    ✅ scikit-learn
#    ✅ boto3
#    ✅ yaml
#
# ==================================================
#  Health check completed!

# %% [markdown]
# ##  3. Pipeline Utility Functions
#
# **Purpose**: Define utility functions for running pipeline commands and monitoring progress.
#
# These functions provide a standardized way to execute pipeline steps, handle errors, and track progress. They maintain the same functionality as the Makefile while adding enhanced logging and error handling for notebook environments.

# %%
def run_pipeline_step(step_name, command, description="", check_files=None, timeout=300):
    """
    Execute a pipeline step with comprehensive logging and error handling
    
    Args:
        step_name: Name of the pipeline step
        command: Command to execute (list or string)
        description: Description of what this step does
        check_files: List of files to verify after execution
        timeout: Timeout in seconds
    """
    print(f"\n EXECUTING: {step_name}")
    print(f" Description: {description}")
    print(f" Started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print("-" * 60)
    
    start_time = time.time()
    
    try:
        if isinstance(command, str):
            command = command.split()
        
        # Execute command
        result = subprocess.run(
            command,
            cwd=PROJECT_ROOT,
            capture_output=True,
            text=True,
            timeout=timeout
        )
        
        execution_time = time.time() - start_time
        
        if result.returncode == 0:
            print(f" {step_name} completed successfully")
            print(f" Execution time: {execution_time:.2f} seconds")
            
            # Show stdout if available
            if result.stdout.strip():
                print(f" Output:\n{result.stdout}")
            
            # Verify output files if specified
            if check_files:
                print(f"\n Verifying output files:")
                for file_path in check_files:
                    full_path = PROJECT_ROOT / file_path
                    if full_path.exists():
                        print(f"    {file_path}")
                    else:
                        print(f"    {file_path} - Not found")
            
            return True
            
        else:
            print(f" {step_name} failed with return code {result.returncode}")
            print(f" Execution time: {execution_time:.2f} seconds")
            
            if result.stderr.strip():
                print(f" Error output:\n{result.stderr}")
            if result.stdout.strip():
                print(f" Standard output:\n{result.stdout}")
            
            return False
            
    except subprocess.TimeoutExpired:
        print(f" {step_name} timed out after {timeout} seconds")
        return False
        
    except Exception as e:
        execution_time = time.time() - start_time
        print(f" {step_name} failed with exception: {e}")
        print(f" Execution time: {execution_time:.2f} seconds")
        return False

def run_python_script(script_path, args=None, description=""):
    """
    Run a Python script with arguments
    
    Args:
        script_path: Path to Python script relative to project root
        args: List of command line arguments
        description: Description of the script
    """
    command = ['python3', str(script_path)]
    if args:
        command.extend(args)
    
    script_name = Path(script_path).name
    return run_pipeline_step(
        step_name=f"Python Script: {script_name}",
        command=command,
        description=description
    )

def create_directories():
    """Create necessary project directories"""
    directories = [
        'data/raw',
        'data/processed', 
        'data/validation',
        'data/monitoring/logs',
        'data/monitoring/reports',
        'data/monitoring/metrics',
        'models',
        'reports'
    ]
    
    print(" Creating project directories...")
    for directory in directories:
        dir_path = PROJECT_ROOT / directory
        dir_path.mkdir(parents=True, exist_ok=True)
        print(f"    {directory}")
    
    print(" All directories created successfully!")

def show_pipeline_status(pipeline_name, steps_completed, total_steps, current_step=""):
    """
    Display pipeline progress
    """
    progress = (steps_completed / total_steps) * 100
    progress_bar = "" * int(progress // 5) + "" * (20 - int(progress // 5))
    
    print(f"\n {pipeline_name} Progress: [{progress_bar}] {progress:.1f}%")
    print(f" Step {steps_completed}/{total_steps}: {current_step}")
    print("-" * 60)

print(" Pipeline utility functions loaded successfully!")
# Out:
#  Pipeline utility functions loaded successfully!

# %% [markdown]
# ##  4. Data Pipeline - Complete Workflow
#
# **Purpose**: Execute the complete data pipeline including validation, feature engineering, and infrastructure setup.
#
# This pipeline performs:
# 1. **Data Validation**: Comprehensive checks for data quality, schema validation, and consistency
# 2. **Feature Engineering**: Transform raw data into ML-ready features with time series components
# 3. **Feature Store Setup**: Configure SageMaker Feature Store for ML workflows
# 4. **Athena Integration**: Setup analytics tables for business intelligence
#
# **Equivalent Makefile Commands**:
# - `make pipeline-data-full`
# - `make pipeline-bi`

# %%
def run_data_pipeline_full(include_bi=True):
    """
    Execute the complete data pipeline with all integrations
    
    Args:
        include_bi: Whether to include business intelligence setup
    """
    pipeline_name = "Complete Data Pipeline"
    total_steps = 6 if include_bi else 4
    current_step = 0
    
    print(f"\n STARTING: {pipeline_name}")
    print("=" * 70)
    
    # Create necessary directories
    create_directories()
    
    # Step 1: Data Validation
    current_step += 1
    show_pipeline_status(pipeline_name, current_step, total_steps, "Data Validation")
    
    success = run_python_script(
        script_path='src/data_processing/data_validation.py',
        args=[
            '--config', 'config.yaml',
            '--data-path', 'data/raw/',
            '--output-path', 'data/validation/'
        ],
        description="Validate data quality, schema, and consistency"
    )
    
    if not success:
        print(" Data pipeline failed at validation step")
        return False
    
    # Step 2: Feature Engineering
    current_step += 1
    show_pipeline_status(pipeline_name, current_step, total_steps, "Feature Engineering")
    
    success = run_python_script(
        script_path='src/data_processing/feature_engineering.py',
        args=[
            '--config', 'config.yaml',
            '--data-path', 'data/raw/',
            '--output-path', 'data/processed/'
        ],
        description="Generate ML-ready features with time series components"
    )
    
    if not success:
        print(" Data pipeline failed at feature engineering step")
        return False
    
    # Step 3: Feature Store & Athena Setup
    current_step += 1
    show_pipeline_status(pipeline_name, current_step, total_steps, "Infrastructure Setup")
    
    success = run_python_script(
        script_path='src/data_processing/feature_store_integration.py',
        args=[
            '--config', 'config.yaml',
            '--data-path', 'data/processed/',
            '--all'  # Setup both Feature Store and Athena
        ],
        description="Setup SageMaker Feature Store and Athena tables"
    )
    
    if not success:
        print(" Data pipeline failed at infrastructure setup")
        return False
    
    # Step 4: Verify Athena Setup
    current_step += 1
    show_pipeline_status(pipeline_name, current_step, total_steps, "Athena Verification")
    
    try:
        athena_client = boto3.client('athena', region_name=config['aws']['region'])
        
        # Test query to verify tables
        query = "SHOW TABLES IN demand_stock_forecasting_mlops_feature_store"
        response = athena_client.start_query_execution(
            QueryString=query,
            ResultConfiguration={
                'OutputLocation': config['aws']['athena']['query_results_location']
            },
            WorkGroup=config['aws']['athena'].get('workgroup', 'primary')
        )
        
        print(f" Athena verification completed")
        print(f" Query ID: {response['QueryExecutionId']}")
        
    except Exception as e:
        print(f" Athena verification failed: {e}")
    
    if include_bi:
        # Step 5: Run Sample Queries (BI)
        current_step += 1
        show_pipeline_status(pipeline_name, current_step, total_steps, "Business Intelligence Queries")
        
        success = run_python_script(
            script_path='scripts/run_sample_queries.py',
            description="Execute sample BI queries for analytics validation"
        )
        
        if not success:
            print(" BI queries failed, but data pipeline is functional")
    
    # Final status
    current_step = total_steps
    show_pipeline_status(pipeline_name, current_step, total_steps, "Completed")
    
    print(f"\n {pipeline_name} completed successfully!")
    print("\n NEXT STEPS:")
    print("   1.  Open AWS Athena Console")
    print("   2.  Select 'demand_stock_forecasting_mlops_feature_store' database")
    print("   3.  Run: SHOW TABLES")
    print("   4.  Query features: SELECT * FROM features_complete LIMIT 10")
    print("   5.  Ready for model training!")
    
    return True

# Execute the complete data pipeline
print(" Ready to run complete data pipeline...")
print(" This includes: validation → feature engineering → infrastructure setup → BI")
print("\n Click 'Run' to start the pipeline or set run_pipeline=False to skip")

# Set this to True to run the pipeline
run_pipeline = True

if run_pipeline:
    pipeline_success = run_data_pipeline_full(include_bi=True)
    if pipeline_success:
        print("\n Data pipeline execution completed successfully!")
    else:
        print("\n Data pipeline execution failed. Check logs for details.")
else:
    print(" Pipeline execution skipped. Set run_pipeline=True to execute.")
# Out:
#  Ready to run complete data pipeline...
#  This includes: validation → feature engineering → infrastructure setup → BI
#
#  Click 'Run' to start the pipeline or set run_pipeline=False to skip
#
#  STARTING: Complete Data Pipeline
# ======================================================================
#  Creating project directories...
#     data/raw
#     data/processed
#     data/validation
#     data/monitoring/logs
#     data/monitoring/reports
#     data/monitoring/metrics
#     models
#     reports
#  All directories created successfully!
#
#  Complete Data Pipeline Progress: [] 16.7%
#  Step 1/6: Data Validation
# ------------------------------------------------------------
#
#  EXECUTING: Python Script: data_validation.py
#  Description: Validate data quality, schema, and consistency
#  Started at: 2025-06-23 15:36:34
# ------------------------------------------------------------
#  Python Script: data_validation.py completed successfully
#  Execution time: 1.82 seconds
#  Output:
#
# ============================================================
# DATA VALIDATION SUMMARY
# ============================================================
# Files Validated: 4
# Overall Quality Score: 97.49/100
# Validation Status: PASSED
#
#
#  Complete Data Pipeline Progress: [] 33.3%
#  Step 2/6: Feature Engineering
# ------------------------------------------------------------
#
#  EXECUTING: Python Script: feature_engineering.py
#  Description: Generate ML-ready features with time series components
#  Started at: 2025-06-23 15:36:36
# ------------------------------------------------------------
#  Python Script: feature_engineering.py completed successfully
#  Execution time: 8.91 seconds
#  Output:
#
# ============================================================
# FEATURE ENGINEERING SUMMARY
# ============================================================
# train: data/processed/train.parquet
# validation: data/processed/validation.parquet
# test: data/processed/test.parquet
# features_complete: data/processed/features_complete.parquet
# metadata: data/processed/feature_metadata.json
#
# Feature engineering completed successfully!
#
#
#  Complete Data Pipeline Progress: [] 50.0%
#  Step 3/6: Infrastructure Setup
# ------------------------------------------------------------
#
#  EXECUTING: Python Script: feature_store_integration.py
#  Description: Setup SageMaker Feature Store and Athena tables
#  Started at: 2025-06-23 15:36:45
# ------------------------------------------------------------
#  Python Script: feature_store_integration.py completed successfully
#  Execution time: 46.14 seconds
#  Output:
#
# ============================================================
# FINAL FIXED FEATURE STORE INTEGRATION SUMMARY
# ============================================================
# Feature Store:
#   Feature Group: demand-stock-forecasting-mlops-features-complete
#   Feature Group ARN: arn:aws:sagemaker:us-east-1:346761359662:feature-group/demand-stock-forecasting-mlops-features-complete
#   Total Features: 103
#   Sample Records: 10
#   Database: demand_stock_forecasting_mlops_feature_store
#
# Athena Integration:
#   Database Created: True
#   S3 Reorganized: True
#   Tables Created:
#     ✓ features_complete
#     ✓ train_data
#     ✓ validation_data
#     ✓ test_data
#    Test Query: SUCCESS (46595 records)
#
# Integration completed!
#
#  Your Athena integration is working!
#  Run: python3 scripts/run_sample_queries.py
#
#
#  Complete Data Pipeline Progress: [] 66.7%
#  Step 4/6: Athena Verification
# ------------------------------------------------------------
#  Athena verification completed
#  Query ID: e32fe17b-d7f6-4f53-846d-47d3adec9d60
#
#  Complete Data Pipeline Progress: [] 83.3%
#  Step 5/6: Business Intelligence Queries
# ------------------------------------------------------------
#
#  EXECUTING: Python Script: run_sample_queries.py
#  Description: Execute sample BI queries for analytics validation
#  Started at: 2025-06-23 15:37:31
# ------------------------------------------------------------
#  Python Script: run_sample_queries.py completed successfully
#  Execution time: 16.45 seconds
#  Output:
# 🔍 Running Fixed Sample Business Intelligence Queries
# ============================================================
#
# 1. Total Records Count
#    Query: SELECT COUNT(*) as total_records FROM demand_stock_forecasting_mlops_feature_sto...
#    Query ID: b5030664-c4d1-42b9-a6cd-1c3b00cab6f3
#    Results:
#    total_records
#    -------------
#    46595
#
# 2. Unique Items Count
#    Query: SELECT COUNT(DISTINCT "Item Code") as unique_items FROM demand_stock_forecasting...
#    Query ID: c7cc677c-abe4-4be1-b01f-254195745073
#    Results:
#    unique_items
#    ------------
#    246
#
# 3. Date Range
#    Query: SELECT MIN("Date") as earliest_date, MAX("Date") as latest_date FROM demand_stoc...
#    Query ID: cb300157-d677-494a-903d-35bffa7ee760
#    Results:
#    earliest_date  |  latest_date
#    -----------------------------
#    2020-07-01 00:00:00.000  |  2023-06-30 00:00:00.000
#
# 4. Revenue Summary
#    Query: SELECT SUM("Revenue") as total_revenue, AVG("Revenue") as avg_revenue FROM deman...
#    Query ID: 2339384e-848a-4038-8f3c-192421b42dab
#    Results:
#    total_revenue  |  avg_revenue
#    -----------------------------
#    3372704.6640549675  |  72.38340302725544
#
# 5. Top Categories by Records
#    Query: SELECT "Category Name", COUNT(*) as records FROM demand_stock_forecasting_mlops_...
#    Query ID: 30ad230e-3791-4cc3-b495-b16b6f8d5958
#    Results:
#    Category Name  |  records
#    -------------------------
#    Flower/Leaf Vegetables  |  18090
#    Capsicum  |  10756
#    Edible Mushroom  |  9458
#    Aquatic Tuberous Vegetables  |  3210
#    Solanum  |  3207
#
# ============================================================
#  Query Results Summary
# ============================================================
# ✓ Total Records Count: SUCCESS
# ✓ Unique Items Count: SUCCESS
# ✓ Date Range: SUCCESS
# ✓ Revenue Summary: SUCCESS
# ✓ Top Categories by Records: SUCCESS
#
#  5/5 queries completed successfully
#
#  All sample queries completed successfully!
#  Your Athena integration is working perfectly!
#
#  Next Steps:
#    • Open AWS Athena Console
#    • Use database: demand_stock_forecasting_mlops_feature_store
#    • Try your own custom queries!
#
#  Testing Simple Query
# ==============================
# ✓ Simple query submitted: a3991943-ed18-498c-a649-a1dc33f6bd47
# ✓ Check Athena console for results!
# ✓ Query status: FAILED
#
#
#  Complete Data Pipeline Progress: [] 100.0%
#  Step 6/6: Completed
# ------------------------------------------------------------
#
#  Complete Data Pipeline completed successfully!
#
#  NEXT STEPS:
#    1.  Open AWS Athena Console
#    2.  Select 'demand_stock_forecasting_mlops_feature_store' database
#    3.  Run: SHOW TABLES
#    4.  Query features: SELECT * FROM features_complete LIMIT 10
#    5.  Ready for model training!
#
#  Data pipeline execution completed successfully!

# %% [markdown]
# ##  5. Model Training & Registry Pipeline
#
# **Purpose**: Train machine learning models and register them to SageMaker Model Registry.
#
# This pipeline performs:
# 1. **Model Training**: Train multiple forecasting models with cross-validation
# 2. **Model Evaluation**: Comprehensive performance evaluation and comparison
# 3. **Model Registration**: Register best models to SageMaker Model Registry
# 4. **Version Management**: Automatic versioning and metadata tracking
#
# **Features**:
# - Automated hyperparameter tuning
# - Multiple model architectures (ARIMA, Random Forest, XGBoost)
# - Performance metrics calculation
# - Model artifact management
#
# **Equivalent Makefile Commands**:
# - `make train-models`
# - `make register-models`
# - `make pipeline-train-full`

# %%
def run_training_pipeline():
    """
    Execute the complete model training and registration pipeline
    """
    pipeline_name = "Model Training & Registry Pipeline"
    total_steps = 4
    current_step = 0
    
    print(f"\n STARTING: {pipeline_name}")
    print("=" * 70)
    
    # Generate model version
    model_version = f"v{datetime.now().strftime('%Y%m%d_%H%M%S')}"
    print(f" Model Version: {model_version}")
    
    # Step 1: Model Training
    current_step += 1
    show_pipeline_status(pipeline_name, current_step, total_steps, "Model Training")
    
    success = run_python_script(
        script_path='src/training/train_model.py',
        args=[
            '--config', 'config.yaml',
            '--data-path', 'data/processed/',
            '--output-path', 'models/',
            '--model-version', model_version,
            '--forecast-horizon', '1'
        ],
        description="Train forecasting models with evaluation"
    )
    
    if not success:
        print(" Training pipeline failed at model training step")
        return False
    
    # Step 2: Verify Model Artifacts
    current_step += 1
    show_pipeline_status(pipeline_name, current_step, total_steps, "Model Verification")
    
    models_path = PROJECT_ROOT / 'models'
    
    # Check for required model files
    required_files = [
        'best_model.pkl',
        'evaluation.json'
    ]
    
    print(" Verifying model artifacts:")
    all_files_exist = True
    
    for file_name in required_files:
        file_path = models_path / file_name
        if file_path.exists():
            file_size = file_path.stat().st_size
            print(f"    {file_name} ({file_size:,} bytes)")
        else:
            print(f"    {file_name} - Missing")
            all_files_exist = False
    
    if not all_files_exist:
        print(" Some model artifacts are missing")
        return False
    
    # Load and display evaluation metrics
    try:
        eval_path = models_path / 'evaluation.json'
        with open(eval_path, 'r') as f:
            evaluation = json.load(f)
        
        print("\n Model Performance Metrics:")
        for metric, value in evaluation.items():
            if isinstance(value, (int, float)):
                print(f"   • {metric}: {value:.4f}")
            else:
                print(f"   • {metric}: {value}")
    
    except Exception as e:
        print(f" Could not load evaluation metrics: {e}")
    
    # Step 3: Model Registration
    current_step += 1
    show_pipeline_status(pipeline_name, current_step, total_steps, "Model Registration")
    
    success = run_python_script(
        script_path='src/deployment/model_registry.py',
        args=[
            '--config', 'config.yaml',
            '--action', 'register',
            '--models-dir', 'models',
            '--evaluation-file', 'models/evaluation.json'
        ],
        description="Register trained models to SageMaker Model Registry"
    )
    
    if not success:
        print(" Training pipeline failed at model registration step")
        return False
    
    # Step 4: List Registered Models
    current_step += 1
    show_pipeline_status(pipeline_name, current_step, total_steps, "Registry Verification")
    
    success = run_python_script(
        script_path='src/deployment/model_registry.py',
        args=[
            '--config', 'config.yaml',
            '--action', 'list'
        ],
        description="List all registered model versions"
    )
    
    if not success:
        print(" Model listing failed, but registration may have succeeded")
    
    # Final status
    show_pipeline_status(pipeline_name, total_steps, total_steps, "Completed")
    
    print(f"\n {pipeline_name} completed successfully!")
    print(f"\n RESULTS:")
    print(f"   •  Model Version: {model_version}")
    print(f"   •  Artifacts saved in: models/")
    print(f"   •  Registered to SageMaker Model Registry")
    
    print("\n NEXT STEPS:")
    print("   1.  Deploy to development: Run deployment pipeline")
    print("   2.  Test endpoint functionality")
    print("   3.  Monitor model performance")
    print("   4.  Promote to staging when ready")
    
    return True

# Execute the training pipeline
print(" Ready to run model training pipeline...")
print(" This includes: training → evaluation → registration → verification")
print("\n Click 'Run' to start the pipeline or set run_training=False to skip")

# Set this to True to run the training pipeline
run_training = True

if run_training:
    training_success = run_training_pipeline()
    if training_success:
        print("\n Training pipeline execution completed successfully!")
    else:
        print("\n Training pipeline execution failed. Check logs for details.")
else:
    print(" Training pipeline execution skipped. Set run_training=True to execute.")
# Out:
#  Ready to run model training pipeline...
#  This includes: training → evaluation → registration → verification
#
#  Click 'Run' to start the pipeline or set run_training=False to skip
#
#  STARTING: Model Training & Registry Pipeline
# ======================================================================
#  Model Version: v20250623_153819
#
#  Model Training & Registry Pipeline Progress: [] 25.0%
#  Step 1/4: Model Training
# ------------------------------------------------------------
#
#  EXECUTING: Python Script: train_model.py
#  Description: Train forecasting models with evaluation
#  Started at: 2025-06-23 15:38:19
# ------------------------------------------------------------
#  Python Script: train_model.py completed successfully
#  Execution time: 100.81 seconds
#  Output:
# 2025-06-23 15:38:19,696 - ModelTrainer - INFO - ============================================================
# 2025-06-23 15:38:19,696 - ModelTrainer - INFO - LOGGING SETUP COMPLETED
# 2025-06-23 15:38:19,696 - ModelTrainer - INFO - ============================================================
# 2025-06-23 15:38:19,696 - ModelTrainer - INFO - Model Version: v20250623_153819
# 2025-06-23 15:38:19,696 - ModelTrainer - INFO - Detailed Log: logs/training_v20250623_153819_20250623_153819.log
# 2025-06-23 15:38:19,696 - ModelTrainer - INFO - Summary Log: logs/training_summary_v20250623_153819_20250623_153819.log
# 2025-06-23 15:38:19,697 - ModelTrainer - INFO - Log Directory: /home/sagemaker-user/demand-stock-forecasting-mlops/logs
# 2025-06-23 15:38:19,697 - ModelTrainer - INFO - ============================================================
# 2025-06-23 15:38:19,711 - ModelTrainer - INFO - ModelTrainer initialized with version: v20250623_153819
# 2025-06-23 15:38:19,711 - ModelTrainer - WARNING - ============================================================
# 2025-06-23 15:38:19,711 - ModelTrainer - WARNING - STARTING COMPLETE TRAINING PIPELINE
# 2025-06-23 15:38:19,711 - ModelTrainer - WARNING - ============================================================
# 2025-06-23 15:38:19,711 - ModelTrainer - INFO - Step 1: Loading processed data...
# 2025-06-23 15:38:19,711 - ModelTrainer - INFO - Loading processed feature data...
# 2025-06-23 15:38:19,774 - ModelTrainer - INFO - Loaded training data: (32616, 105)
# 2025-06-23 15:38:19,782 - ModelTrainer - INFO - Loaded validation data: (6989, 105)
# 2025-06-23 15:38:19,790 - ModelTrainer - INFO - Loaded test data: (6990, 105)
# 2025-06-23 15:38:19,803 - ModelTrainer - INFO - Step 2: Preparing features and targets...
# 2025-06-23 15:38:19,803 - ModelTrainer - INFO - Preparing features for 1-day forecast...
# 2025-06-23 15:38:20,027 - ModelTrainer - INFO - Features prepared: (32616, 90), Target: (32616,)
# 2025-06-23 15:38:20,027 - ModelTrainer - INFO - Feature columns: 90
# 2025-06-23 15:38:20,027 - ModelTrainer - WARNING - FEATURE PREPARATION COMPLETED - 90 features ready
# 2025-06-23 15:38:20,027 - ModelTrainer - INFO - Preparing features for 1-day forecast...
# 2025-06-23 15:38:20,088 - ModelTrainer - INFO - Features prepared: (6989, 90), Target: (6989,)
# 2025-06-23 15:38:20,088 - ModelTrainer - INFO - Feature columns: 90
# 2025-06-23 15:38:20,088 - ModelTrainer - WARNING - FEATURE PREPARATION COMPLETED - 90 features ready
# 2025-06-23 15:38:20,088 - ModelTrainer - INFO - Preparing features for 1-day forecast...
# 2025-06-23 15:38:20,149 - ModelTrainer - INFO - Features prepared: (6990, 90), Target: (6990,)
# 2025-06-23 15:38:20,149 - ModelTrainer - INFO - Feature columns: 90
# 2025-06-23 15:38:20,149 - ModelTrainer - WARNING - FEATURE PREPARATION COMPLETED - 90 features ready
# 2025-06-23 15:38:20,149 - ModelTrainer - INFO - Step 3: Training models...
# 2025-06-23 15:38:20,149 - ModelTrainer - WARNING - STARTING MODEL TRAINING PHASE
# 2025-06-23 15:38:20,149 - ModelTrainer - INFO - Training models...
# 2025-06-23 15:38:20,149 - ModelTrainer - WARNING - TRAINING LINEAR_REGRESSION...
# 2025-06-23 15:38:20,149 - ModelTrainer - INFO - Scaling features for linear_regression
# 2025-06-23 15:38:20,370 - ModelTrainer - INFO - linear_regression training completed in 0.22 seconds
# 2025-06-23 15:38:20,374 - ModelTrainer - WARNING - linear_regression - Validation MAPE: 11.701%
# 2025-06-23 15:38:20,374 - ModelTrainer - INFO - linear_regression - Validation RMSE: 1.335
# 2025-06-23 15:38:20,374 - ModelTrainer - INFO - linear_regression - Validation R²: 0.950
# 2025-06-23 15:38:20,374 - ModelTrainer - WARNING - TRAINING RIDGE...
# 2025-06-23 15:38:20,374 - ModelTrainer - INFO - Scaling features for ridge
# 2025-06-23 15:38:20,533 - ModelTrainer - INFO - ridge training completed in 0.16 seconds
# 2025-06-23 15:38:20,538 - ModelTrainer - WARNING - ridge - Validation MAPE: 11.692%
# 2025-06-23 15:38:20,538 - ModelTrainer - INFO - ridge - Validation RMSE: 1.335
# 2025-06-23 15:38:20,538 - ModelTrainer - INFO - ridge - Validation R²: 0.950
# 2025-06-23 15:38:20,538 - ModelTrainer - WARNING - TRAINING RANDOM_FOREST...
# 2025-06-23 15:38:23,623 - ModelTrainer - INFO - random_forest training completed in 3.09 seconds
# 2025-06-23 15:38:23,715 - ModelTrainer - WARNING - random_forest - Validation MAPE: 11.694%
# 2025-06-23 15:38:23,716 - ModelTrainer - INFO - random_forest - Validation RMSE: 1.450
# 2025-06-23 15:38:23,716 - ModelTrainer - INFO - random_forest - Validation R²: 0.941
# 2025-06-23 15:38:23,716 - ModelTrainer - WARNING - TRAINING GRADIENT_BOOSTING...
# 2025-06-23 15:39:59,527 - ModelTrainer - INFO - gradient_boosting training completed in 95.81 seconds
# 2025-06-23 15:39:59,532 - ModelTrainer - WARNING - gradient_boosting - Validation MAPE: 11.878%
# 2025-06-23 15:39:59,532 - ModelTrainer - INFO - gradient_boosting - Validation RMSE: 1.444
# 2025-06-23 15:39:59,532 - ModelTrainer - INFO - gradient_boosting - Validation R²: 0.941
# 2025-06-23 15:39:59,532 - ModelTrainer - WARNING - MODEL TRAINING PHASE COMPLETED
# 2025-06-23 15:39:59,533 - ModelTrainer - INFO - Step 4: Evaluating on test set...
# 2025-06-23 15:39:59,533 - ModelTrainer - WARNING - STARTING TEST SET EVALUATION
# 2025-06-23 15:39:59,533 - ModelTrainer - INFO - Evaluating models on test set...
# 2025-06-23 15:39:59,533 - ModelTrainer - INFO - Evaluating linear_regression on test set...
# 2025-06-23 15:39:59,554 - ModelTrainer - WARNING - linear_regression - Test MAPE: 7.048%
# 2025-06-23 15:39:59,555 - ModelTrainer - INFO - linear_regression - Test RMSE: 2.031
# 2025-06-23 15:39:59,555 - ModelTrainer - INFO - linear_regression - Test R²: 0.919
# 2025-06-23 15:39:59,555 - ModelTrainer - INFO - Evaluating ridge on test set...
# 2025-06-23 15:39:59,585 - ModelTrainer - WARNING - ridge - Test MAPE: 7.042%
# 2025-06-23 15:39:59,586 - ModelTrainer - INFO - ridge - Test RMSE: 2.031
# 2025-06-23 15:39:59,586 - ModelTrainer - INFO - ridge - Test R²: 0.919
# 2025-06-23 15:39:59,586 - ModelTrainer - INFO - Evaluating random_forest on test set...
# 2025-06-23 15:39:59,633 - ModelTrainer - WARNING - random_forest - Test MAPE: 7.096%
# 2025-06-23 15:39:59,633 - ModelTrainer - INFO - random_forest - Test RMSE: 1.883
# 2025-06-23 15:39:59,633 - ModelTrainer - INFO - random_forest - Test R²: 0.931
# 2025-06-23 15:39:59,633 - ModelTrainer - INFO - Evaluating gradient_boosting on test set...
# 2025-06-23 15:39:59,657 - ModelTrainer - WARNING - gradient_boosting - Test MAPE: 8.037%
# 2025-06-23 15:39:59,657 - ModelTrainer - INFO - gradient_boosting - Test RMSE: 1.885
# 2025-06-23 15:39:59,657 - ModelTrainer - INFO - gradient_boosting - Test R²: 0.931
# 2025-06-23 15:39:59,657 - ModelTrainer - WARNING - TEST SET EVALUATION COMPLETED
# 2025-06-23 15:39:59,657 - ModelTrainer - INFO - Step 5: Selecting best model...
# 2025-06-23 15:39:59,657 - ModelTrainer - WARNING - BEST MODEL SELECTED: ridge (MAPE: 11.692%)
# 2025-06-23 15:39:59,657 - ModelTrainer - INFO - Step 6: Saving models and results...
# 2025-06-23 15:39:59,657 - ModelTrainer - WARNING - SAVING MODELS AND RESULTS
# 2025-06-23 15:39:59,657 - ModelTrainer - INFO - Saving models and results...
# 2025-06-23 15:39:59,658 - ModelTrainer - INFO - Saved linear_regression model (0.01 MB)
# 2025-06-23 15:39:59,659 - ModelTrainer - INFO - Saved ridge model (0.01 MB)
# 2025-06-23 15:39:59,689 - ModelTrainer - INFO - Saved random_forest model (4.90 MB)
# 2025-06-23 15:39:59,693 - ModelTrainer - INFO - Saved gradient_boosting model (0.71 MB)
# 2025-06-23 15:39:59,694 - ModelTrainer - WARNING - BEST MODEL SAVED: ridge -> best_model.pkl (MAPE: 11.692%)
# 2025-06-23 15:39:59,694 - ModelTrainer - INFO - Saved evaluation results: models/evaluation.json
# 2025-06-23 15:39:59,694 - ModelTrainer - INFO - Saved feature info: models/feature_info.json
# 2025-06-23 15:39:59,694 - ModelTrainer - WARNING - SAVED 7 FILES TO models/
# 2025-06-23 15:39:59,694 - ModelTrainer - WARNING - ============================================================
# 2025-06-23 15:39:59,694 - ModelTrainer - WARNING - TRAINING PIPELINE COMPLETED SUCCESSFULLY!
# 2025-06-23 15:39:59,694 - ModelTrainer - WARNING - ============================================================
#
# ============================================================
# MODEL TRAINING SUMMARY
# ============================================================
# Model Version: v20250623_153819
# Status: SUCCESS
# Models Trained: 4
# Best Model: ridge
#
# Best Model Performance:
#   train_mae: 0.506
#   train_mse: 1.990
#   train_rmse: 1.411
#   train_r2: 0.964
#   train_mape: 5.326%
#   val_mae: 0.682
#   val_mse: 1.782
#   val_rmse: 1.335
#   val_r2: 0.950
#   val_mape: 11.692%
#   val_smape: 10.632%
#   test_mae: 0.508
#   test_rmse: 2.031
#   test_r2: 0.919
#   test_mape: 7.042%
#
# Output Path: models/
# Log Files: logs/training_v20250623_153819_*.log
# 2025-06-23 15:39:59,697 - ModelTrainer - WARNING - ============================================================
# 2025-06-23 15:39:59,697 - ModelTrainer - WARNING - MAIN FUNCTION COMPLETED SUCCESSFULLY
# 2025-06-23 15:39:59,697 - ModelTrainer - WARNING - ============================================================
#
#
#  Model Training & Registry Pipeline Progress: [] 50.0%
#  Step 2/4: Model Verification
# ------------------------------------------------------------
# 🔍 Verifying model artifacts:
#     best_model.pkl (5,713 bytes)
#     evaluation.json (2,264 bytes)
#
#  Model Performance Metrics:
#    • linear_regression: {'train_mae': 0.5056392079113663, 'train_mse': 1.9901760680814276, 'train_rmse': 1.4107360022631548, 'train_r2': 0.9638075015862446, 'train_mape': 5.326947686158999, 'val_mae': 0.6822868409481369, 'val_mse': 1.782934245278001, 'val_rmse': 1.3352656085131531, 'val_r2': 0.9497227795058321, 'val_mape': 11.700506739624721, 'val_smape': 10.638298186022938, 'test_mae': 0.5081868771827537, 'test_rmse': 2.0306325693299363, 'test_r2': 0.9193960002380387, 'test_mape': 7.047639291529275}
#    • ridge: {'train_mae': 0.5055338660970473, 'train_mse': 1.990184858148421, 'train_rmse': 1.4107391176785384, 'train_r2': 0.9638073417338121, 'train_mape': 5.325620147346603, 'val_mae': 0.6820620062017853, 'val_mse': 1.7822698839782376, 'val_rmse': 1.3350168103729023, 'val_r2': 0.9497415139261532, 'val_mape': 11.692430365041805, 'val_smape': 10.631585432941227, 'test_mae': 0.5079574189347851, 'test_rmse': 2.030536284385137, 'test_r2': 0.9194036439327055, 'test_mape': 7.0419568095491964}
#    • random_forest: {'train_mae': 0.35785821509286264, 'train_mse': 0.8691574675887455, 'train_rmse': 0.9322861511299766, 'train_r2': 0.9841938706974129, 'train_mape': 3.957731546751506, 'val_mae': 0.6855342038201652, 'val_mse': 2.103475088938849, 'val_rmse': 1.4503361985894336, 'val_r2': 0.9406838019233412, 'val_mape': 11.693978746604545, 'val_smape': 10.573899042277699, 'test_mae': 0.5187141991497498, 'test_rmse': 1.882703232269873, 'test_r2': 0.9307120624147823, 'test_mape': 7.096184142545339}
#    • gradient_boosting: {'train_mae': 0.3571261693633963, 'train_mse': 0.62361417201593, 'train_rmse': 0.7896924540705261, 'train_r2': 0.9886592169941828, 'train_mape': 4.20273825705328, 'val_mae': 0.7012849969372428, 'val_mse': 2.0863257897146914, 'val_rmse': 1.4444119182957096, 'val_r2': 0.9411673974909831, 'val_mape': 11.877940892027047, 'val_smape': 10.652631174154257, 'test_mae': 0.5632813084316265, 'test_rmse': 1.8845635880975533, 'test_r2': 0.9305750637616115, 'test_mape': 8.037326720105682}
#
#  Model Training & Registry Pipeline Progress: [] 75.0%
#  Step 3/4: Model Registration
# ------------------------------------------------------------
#
#  EXECUTING: Python Script: model_registry.py
#  Description: Register trained models to SageMaker Model Registry
#  Started at: 2025-06-23 15:39:59
# ------------------------------------------------------------
#  Python Script: model_registry.py completed successfully
#  Execution time: 14.32 seconds
#  Output:
#
# ============================================================
# MODEL REGISTRATION RESULTS
# ============================================================
# linear_regression: registered
#   Run ID: 44767b2cb3164b36bd7d50a7fb504836
# ridge: registered
#   Run ID: 8cafef91938842029f37294435a4301a
# random_forest: registered
#   Run ID: 91959cd72b2a4e5991661ad9483cefbb
# gradient_boosting: registered
#   Run ID: dcd318d8f9504dcbb5ba530f52512ebb
#
#
#  Model Training & Registry Pipeline Progress: [] 100.0%
#  Step 4/4: Registry Verification
# ------------------------------------------------------------
#
#  EXECUTING: Python Script: model_registry.py
#  Description: List all registered model versions
#  Started at: 2025-06-23 15:40:14
# ------------------------------------------------------------
#  Python Script: model_registry.py failed with return code 1
#  Execution time: 4.28 seconds
#  Error output:
# 2025-06-23 15:40:15.789014: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-23 15:40:15.816813: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-23 15:40:17,799 - model_registry - ERROR - Error setting up MLflow:  Model registry functionality is unavailable; got unsupported URI 's3://sagemaker-us-east-1-346761359662/mlflow' for model registry data storage. Supported URI schemes are: ['', 'file', 'databricks', 'databricks-uc', 'uc', 'http', 'https', 'postgresql', 'mysql', 'sqlite', 'mssql', 'arn']. See https://www.mlflow.org/docs/latest/tracking.html#storage for how to run an MLflow server against one of the supported backend storage locations.
# 2025-06-23 15:40:17,804 - model_registry - WARNING - Using local MLflow tracking as fallback
# 2025-06-23 15:40:17,804 - model_registry - INFO - Model Registry initialized successfully
#
#  Standard output:
# Error: --model-name required for list action
#
#  Model listing failed, but registration may have succeeded
#
#  Model Training & Registry Pipeline Progress: [] 100.0%
#  Step 4/4: Completed
# ------------------------------------------------------------
#
#  Model Training & Registry Pipeline completed successfully!
#
#  RESULTS:
#    •  Model Version: v20250623_153819
#    •  Artifacts saved in: models/
#    •  Registered to SageMaker Model Registry
#
#  NEXT STEPS:
#    1.  Deploy to development: Run deployment pipeline
#    2.  Test endpoint functionality
#    3.  Monitor model performance
#    4.  Promote to staging when ready
#
#  Training pipeline execution completed successfully!

# %% [markdown]
# ##  6. Deployment Pipeline - Multi-Environment
#
# **Purpose**: Deploy trained models across different environments (dev, staging, production).
#
# This pipeline performs:
# 1. **Development Deployment**: Deploy to dev environment for initial testing
# 2. **Staging Deployment**: Deploy to staging for integration testing
# 3. **Production Deployment**: Deploy to production with monitoring
# 4. **Endpoint Testing**: Comprehensive functionality testing
# 5. **Health Monitoring**: Continuous endpoint health checks
#
# **Features**:
# - Multi-environment deployment strategy
# - Automated endpoint testing
# - Blue-green deployment support
# - Rollback capabilities
#
# **Equivalent Makefile Commands**:
# - `make deploy-dev`
# - `make deploy-staging`
# - `make deploy-prod`
# - `make workflow-staging`
# - `make workflow-prod`

# %%
def deploy_to_environment(environment='dev', test_endpoint=True):
    """
    Deploy model to specified environment
    
    Args:
        environment: Target environment ('dev', 'staging', 'prod')
        test_endpoint: Whether to test the endpoint after deployment
    """
    pipeline_name = f"Deployment to {environment.upper()}"
    total_steps = 3 if test_endpoint else 2
    current_step = 0
    
    print(f"\n STARTING: {pipeline_name}")
    print("=" * 70)
    
    # Configuration
    model_name = "chinese_produce_forecaster"
    endpoint_name = f"produce-forecast-{environment}"
    model_path = "models/best_model.pkl"
    
    print(f" Deployment Configuration:")
    print(f"   •  Environment: {environment}")
    print(f"   •  Model: {model_name}")
    print(f"   •  Endpoint: {endpoint_name}")
    print(f"   •  Model Path: {model_path}")
    
    # Step 1: Model Deployment
    current_step += 1
    show_pipeline_status(pipeline_name, current_step, total_steps, "Model Deployment")
    
    success = run_python_script(
        script_path='src/deployment/sagemaker_deploy.py',
        args=[
            '--config', 'config.yaml',
            '--action', 'deploy',
            '--model-path', model_path,
            '--model-name', model_name,
            '--endpoint-name', endpoint_name,
            '--environment', environment
        ],
        description=f"Deploy model to {environment} environment"
    )
    
    if not success:
        print(f" {pipeline_name} failed at deployment step")
        return False
    
    # Step 2: Verify Endpoint Status
    current_step += 1
    show_pipeline_status(pipeline_name, current_step, total_steps, "Endpoint Verification")
    
    try:
        sagemaker_client = boto3.client('sagemaker', region_name=config['aws']['region'])
        
        # Check endpoint status
        response = sagemaker_client.describe_endpoint(EndpointName=endpoint_name)
        endpoint_status = response['EndpointStatus']
        
        print(f"🔍 Endpoint Status: {endpoint_status}")
        
        if endpoint_status == 'InService':
            print(f" Endpoint '{endpoint_name}' is ready for inference")
            creation_time = response['CreationTime']
            print(f" Created: {creation_time}")
        else:
            print(f" Endpoint status: {endpoint_status}")
            
    except Exception as e:
        print(f" Could not verify endpoint status: {e}")
        return False
    
    # Step 3: Test Endpoint (if requested)
    if test_endpoint:
        current_step += 1
        show_pipeline_status(pipeline_name, current_step, total_steps, "Endpoint Testing")
        
        success = run_python_script(
            script_path='src/deployment/sagemaker_deploy.py',
            args=[
                '--config', 'config.yaml',
                '--action', 'test',
                '--endpoint-name', endpoint_name
            ],
            description="Test endpoint functionality with sample data"
        )
        
        if not success:
            print(" Endpoint testing failed, but deployment succeeded")
    
    # Final status
    show_pipeline_status(pipeline_name, total_steps, total_steps, "Completed")
    
    print(f"\n {pipeline_name} completed successfully!")
    print(f"\n DEPLOYMENT SUMMARY:")
    print(f"   •  Environment: {environment}")
    print(f"   •  Endpoint: {endpoint_name}")
    print(f"   •  Status: Ready for inference")
    
    if environment == 'dev':
        print("\n NEXT STEPS:")
        print("   1.  Run integration tests")
        print("   2.  Monitor performance metrics")
        print("   3.  Promote to staging when ready")
    elif environment == 'staging':
        print("\n NEXT STEPS:")
        print("   1.  Run full test suite")
        print("   2.  User acceptance testing")
        print("   3.  Promote to production when approved")
    elif environment == 'prod':
        print("\n NEXT STEPS:")
        print("   1.  Start monitoring pipeline")
        print("   2.  Configure alerts")
        print("   3.  Monitor business metrics")
    
    return True

def run_complete_deployment_workflow():
    """
    Run complete deployment workflow: dev → staging → prod
    """
    print("\n COMPLETE DEPLOYMENT WORKFLOW")
    print("=" * 70)
    print(" This will deploy to: dev → staging → production")
    print(" This process may take 15-30 minutes")
    
    # Deploy to development
    print("\n Phase 1: Development Deployment")
    dev_success = deploy_to_environment('dev', test_endpoint=True)
    
    if not dev_success:
        print(" Development deployment failed. Stopping workflow.")
        return False
    
    # Deploy to staging
    print("\n Phase 2: Staging Deployment")
    staging_success = deploy_to_environment('staging', test_endpoint=True)
    
    if not staging_success:
        print(" Staging deployment failed. Development is still available.")
        return False
    
    # Deploy to production (with monitoring)
    print("\n Phase 3: Production Deployment")
    prod_success = deploy_to_environment('prod', test_endpoint=True)
    
    if not prod_success:
        print(" Production deployment failed. Staging is still available.")
        return False
    
    print("\n COMPLETE DEPLOYMENT WORKFLOW SUCCESSFUL!")
    print("\n ACTIVE ENDPOINTS:")
    print("   •  Development: produce-forecast-dev")
    print("   •  Staging: produce-forecast-staging")
    print("   •  Production: produce-forecast-prod")
    
    return True

# Deployment Options
print(" Ready to run deployment pipeline...")
print("\n DEPLOYMENT OPTIONS:")
print("    Single environment deployment")
print("    Complete workflow (dev → staging → prod)")
print("\n Configure your deployment below:")

# Configuration
deployment_type = "single"  # Options: "single" or "complete"
target_environment = "dev"  # Options: "dev", "staging", "prod"
run_deployment = True      # Set to True to run deployment

if run_deployment:
    if deployment_type == "single":
        deployment_success = deploy_to_environment(target_environment, test_endpoint=True)
    elif deployment_type == "complete":
        deployment_success = run_complete_deployment_workflow()
    else:
        print(" Invalid deployment_type. Use 'single' or 'complete'")
        deployment_success = False
    
    if deployment_success:
        print("\n Deployment pipeline execution completed successfully!")
    else:
        print("\n Deployment pipeline execution failed. Check logs for details.")
else:
    print(" Deployment pipeline execution skipped. Set run_deployment=True to execute.")
# Out:
#  Ready to run deployment pipeline...
#
#  DEPLOYMENT OPTIONS:
#     Single environment deployment
#     Complete workflow (dev → staging → prod)
#
#  Configure your deployment below:
#
#  STARTING: Deployment to DEV
# ======================================================================
#  Deployment Configuration:
#    •  Environment: dev
#    •  Model: chinese_produce_forecaster
#    •  Endpoint: produce-forecast-dev
#    •  Model Path: models/best_model.pkl
#
#  Deployment to DEV Progress: [] 33.3%
#  Step 1/3: Model Deployment
# ------------------------------------------------------------
#
#  EXECUTING: Python Script: sagemaker_deploy.py
#  Description: Deploy model to dev environment
#  Started at: 2025-06-23 15:42:25
# ------------------------------------------------------------
#  Python Script: sagemaker_deploy.py completed successfully
#  Execution time: 244.93 seconds
#  Output:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# -------!
#  DEPLOYMENT COMPLETED SUCCESSFULLY!
#  Endpoint: produce-forecast-dev
#  Model: chinese-produce-forecaster-dev-50693347
#  Environment: dev
#  Instance Type: ml.m5.large
#  Status: deployed
#  Feature Order: Dynamically extracted from model
#
#
#  Deployment to DEV Progress: [] 66.7%
#  Step 2/3: Endpoint Verification
# ------------------------------------------------------------
# 🔍 Endpoint Status: InService
#  Endpoint 'produce-forecast-dev' is ready for inference
#  Created: 2025-06-23 15:42:29.186000+00:00
#
#  Deployment to DEV Progress: [] 100.0%
#  Step 3/3: Endpoint Testing
# ------------------------------------------------------------
#
#  EXECUTING: Python Script: sagemaker_deploy.py
#  Description: Test endpoint functionality with sample data
#  Started at: 2025-06-23 15:46:30
# ------------------------------------------------------------
#  Python Script: sagemaker_deploy.py completed successfully
#  Execution time: 2.08 seconds
#  Output:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
#
#  Endpoint Test Results:
# Status: success
#  Latency: 226.37ms
#  Predictions: 1
#  Test Data: Default sample data
#  Sample Result: {'predictions': [510.10711198864436], 'confidence': [0.85], 'model_type': 'Ridge', 'input_features_count': 90, 'prediction_count': 1, 'timestamp': '2025-06-23T15:46:32.189198', 'status': 'success'}
#
#
#  Deployment to DEV Progress: [] 100.0%
#  Step 3/3: Completed
# ------------------------------------------------------------
#
#  Deployment to DEV completed successfully!
#
#  DEPLOYMENT SUMMARY:
#    •  Environment: dev
#    •  Endpoint: produce-forecast-dev
#    •  Status: Ready for inference
#
#  NEXT STEPS:
#    1.  Run integration tests
#    2.  Monitor performance metrics
#    3.  Promote to staging when ready
#
#  Deployment pipeline execution completed successfully!

# %% [markdown]
# ##  7. Monitoring & Observability Pipeline
#
# **Purpose**: Start comprehensive monitoring systems for deployed models.
#
# This pipeline performs:
# 1. **Performance Monitoring**: Real-time model performance tracking
# 2. **Data Drift Detection**: Monitor input data distribution changes
# 3. **Dashboard Setup**: Interactive monitoring dashboards
# 4. **Alert Configuration**: Automated alerting for anomalies
# 5. **Health Checks**: Continuous system health monitoring
#
# **Features**:
# - Real-time metrics collection
# - Interactive Plotly/Dash dashboards
# - Statistical drift detection algorithms
# - Configurable alerting thresholds
# - Historical performance analysis
#
# **Equivalent Makefile Commands**:
# - `make monitoring-start`
# - `make monitoring-status`
# - `make detect-drift`
# - `make performance-report`

# %%
import subprocess
import psutil
import signal
import socket
from contextlib import closing

def find_free_port(start_port=8050, max_attempts=10):
    """Find a free port starting from start_port"""
    for i in range(max_attempts):
        port = start_port + i
        with closing(socket.socket(socket.AF_INET, socket.SOCK_STREAM)) as sock:
            if sock.connect_ex(('localhost', port)) != 0:
                return port
    return None

def stop_monitoring_processes():
    """Stop all existing monitoring processes"""
    print(" Stopping existing monitoring processes...")
    
    # Kill processes by port
    ports_to_check = [8002, 8050, 8051, 8052]
    for port in ports_to_check:
        try:
            for proc in psutil.process_iter(['pid', 'name', 'connections']):
                if proc.info['connections']:
                    for conn in proc.info['connections']:
                        if hasattr(conn, 'laddr') and conn.laddr.port == port:
                            print(f"    Killing process on port {port} (PID: {proc.pid})")
                            proc.terminate()
                            break
        except (psutil.NoSuchProcess, psutil.AccessDenied):
            continue
    
    # Kill processes by name pattern
    patterns = ['performance_monitor.py', 'drift_detector.py']
    for pattern in patterns:
        try:
            subprocess.run(['pkill', '-f', pattern], 
                         capture_output=True, timeout=5)
        except (subprocess.TimeoutExpired, subprocess.CalledProcessError):
            pass
    
    time.sleep(2)
    print(" Monitoring cleanup completed")

def start_monitoring_component(component_name, script_path, args, background=True):
    """Start a monitoring component"""
    command = ['python3', str(script_path)] + args
    
    try:
        if background:
            process = subprocess.Popen(
                command,
                cwd=PROJECT_ROOT,
                stdout=subprocess.PIPE,
                stderr=subprocess.PIPE,
                text=True
            )
            print(f" {component_name} started (PID: {process.pid})")
            return process
        else:
            result = subprocess.run(
                command,
                cwd=PROJECT_ROOT,
                capture_output=True,
                text=True,
                timeout=30
            )
            if result.returncode == 0:
                print(f" {component_name} executed successfully")
                if result.stdout.strip():
                    print(f"📤 Output: {result.stdout}")
                return True
            else:
                print(f" {component_name} failed: {result.stderr}")
                return False
                
    except Exception as e:
        print(f" Failed to start {component_name}: {e}")
        return None

def run_monitoring_pipeline(start_services=True, run_drift_analysis=True):
    """
    Execute the complete monitoring pipeline
    
    Args:
        start_services: Whether to start background monitoring services
        run_drift_analysis: Whether to run drift detection analysis
    """
    pipeline_name = "Monitoring & Observability Pipeline"
    total_steps = 5 if start_services else 3
    current_step = 0
    
    print(f"\n STARTING: {pipeline_name}")
    print("=" * 70)
    
    # Configuration
    monitoring_interval = 60
    reference_data = "data/processed/train.parquet"
    current_data = "data/processed/validation.parquet"
    
    print(f" Monitoring Configuration:")
    print(f"   •  Interval: {monitoring_interval} seconds")
    print(f"   •  Reference Data: {reference_data}")
    print(f"   •  Current Data: {current_data}")
    
    # Step 1: Stop existing monitoring
    current_step += 1
    show_pipeline_status(pipeline_name, current_step, total_steps, "Cleanup")
    stop_monitoring_processes()
    
    # Step 2: Performance Health Check
    current_step += 1
    show_pipeline_status(pipeline_name, current_step, total_steps, "Performance Check")
    
    success = start_monitoring_component(
        component_name="Performance Health Check",
        script_path='src/monitoring/performance_monitor.py',
        args=[
            '--config', 'config.yaml',
            '--action', 'health',
            '--local-mode'
        ],
        background=False
    )
    
    if not success:
        print(" Performance health check failed, continuing...")
    
    # Step 3: Drift Detection Analysis
    if run_drift_analysis:
        current_step += 1
        show_pipeline_status(pipeline_name, current_step, total_steps, "Drift Analysis")
        
        success = start_monitoring_component(
            component_name="Drift Detection Analysis",
            script_path='src/monitoring/drift_detector.py',
            args=[
                '--config', 'config.yaml',
                '--action', 'detect',
                '--reference-data', reference_data,
                '--current-data', current_data,
                '--local-mode',
                '--generate-report'
            ],
            background=False
        )
        
        if not success:
            print(" Drift analysis failed, continuing...")
    
    if start_services:
        # Step 4: Start Performance Monitor
        current_step += 1
        show_pipeline_status(pipeline_name, current_step, total_steps, "Performance Monitor")
        
        perf_process = start_monitoring_component(
            component_name="Performance Monitor",
            script_path='src/monitoring/performance_monitor.py',
            args=[
                '--config', 'config.yaml',
                '--action', 'start',
                '--interval', str(monitoring_interval),
                '--local-mode'
            ],
            background=True
        )
        
        time.sleep(2)  # Let performance monitor start
        
        # Step 5: Start Drift Monitor
        current_step += 1
        show_pipeline_status(pipeline_name, current_step, total_steps, "Drift Monitor")
        
        drift_process = start_monitoring_component(
            component_name="Drift Monitor",
            script_path='src/monitoring/drift_detector.py',
            args=[
                '--config', 'config.yaml',
                '--action', 'monitor',
                '--reference-data', reference_data,
                '--current-data', current_data,
                '--local-mode',
                '--interval', '60'
            ],
            background=True
        )
        
        time.sleep(3)  # Let drift monitor start
        
        # Try to start dashboard on available port
        dashboard_port = find_free_port(8050)
        if dashboard_port:
            print(f"\n Starting monitoring dashboard on port {dashboard_port}...")
            dashboard_process = start_monitoring_component(
                component_name="Monitoring Dashboard",
                script_path='src/monitoring/performance_monitor.py',
                args=[
                    '--config', 'config.yaml',
                    '--action', 'dashboard',
                    '--port', str(dashboard_port),
                    '--local-mode'
                ],
                background=True
            )
            
            if dashboard_process:
                print(f" Dashboard will be available at: http://localhost:{dashboard_port}")
        
        time.sleep(3)  # Let everything stabilize
    
    # Final status
    show_pipeline_status(pipeline_name, total_steps, total_steps, "Completed")
    
    print(f"\n {pipeline_name} completed successfully!")
    
    if start_services:
        print(f"\n ACTIVE MONITORING SERVICES:")
        print(f"   •  Performance Monitor: Running")
        print(f"   •  Drift Detection: Running")
        if dashboard_port:
            print(f"   •  Dashboard: http://localhost:{dashboard_port}")
        
        print("\n MONITORING COMMANDS:")
        print("   •  Check status: Run monitoring status check below")
        print("   •  Stop services: Run monitoring cleanup below")
        print("   •  View logs: Check data/monitoring/logs/")
    
    print("\n NEXT STEPS:")
    print("   1.  Monitor dashboard for real-time metrics")
    print("   2.  Configure alert thresholds")
    print("   3.  Review performance trends")
    print("   4.  Set up automated reporting")
    
    return True

def check_monitoring_status():
    """Check status of all monitoring components"""
    print("\n MONITORING SYSTEM STATUS")
    print("=" * 50)
    
    # Check running processes
    monitoring_processes = []
    for proc in psutil.process_iter(['pid', 'name', 'cmdline']):
        try:
            cmdline = ' '.join(proc.info['cmdline']) if proc.info['cmdline'] else ''
            if any(pattern in cmdline for pattern in ['performance_monitor.py', 'drift_detector.py']):
                monitoring_processes.append({
                    'pid': proc.info['pid'],
                    'name': proc.info['name'],
                    'cmdline': cmdline
                })
        except (psutil.NoSuchProcess, psutil.AccessDenied):
            continue
    
    if monitoring_processes:
        print(f" Found {len(monitoring_processes)} monitoring processes:")
        for proc in monitoring_processes:
            process_type = "Performance" if "performance_monitor" in proc['cmdline'] else "Drift Detection"
            print(f"   • {process_type}: PID {proc['pid']}")
    else:
        print(" No monitoring processes found")
    
    # Check port usage
    ports_to_check = [8002, 8050, 8051, 8052]
    print("\n Port Status:")
    for port in ports_to_check:
        with closing(socket.socket(socket.AF_INET, socket.SOCK_STREAM)) as sock:
            if sock.connect_ex(('localhost', port)) == 0:
                print(f"   • Port {port}:  In Use")
            else:
                print(f"   • Port {port}: ⚪ Available")
    
    return len(monitoring_processes) > 0

# Execute monitoring pipeline
print(" Ready to run monitoring pipeline...")
print(" This includes: performance monitoring + drift detection + dashboards")
print("\n Configure your monitoring below:")

# Configuration
start_background_services = True  # Start continuous monitoring services
run_analysis_only = False        # Run one-time analysis instead
run_monitoring = True            # Set to True to execute

if run_monitoring:
    if run_analysis_only:
        monitoring_success = run_monitoring_pipeline(start_services=False, run_drift_analysis=True)
    else:
        monitoring_success = run_monitoring_pipeline(start_services=start_background_services, run_drift_analysis=True)
    
    if monitoring_success:
        print("\n Monitoring pipeline execution completed successfully!")
    else:
        print("\n Monitoring pipeline execution failed. Check logs for details.")
else:
    print(" Monitoring pipeline execution skipped. Set run_monitoring=True to execute.")
# Out:
#  Ready to run monitoring pipeline...
#  This includes: performance monitoring + drift detection + dashboards
#
#  Configure your monitoring below:
#
#  STARTING: Monitoring & Observability Pipeline
# ======================================================================
#  Monitoring Configuration:
#    •  Interval: 60 seconds
#    •  Reference Data: data/processed/train.parquet
#    •  Current Data: data/processed/validation.parquet
#
#  Monitoring & Observability Pipeline Progress: [] 20.0%
#  Step 1/5: Cleanup
# ------------------------------------------------------------
#  Stopping existing monitoring processes...
#     Killing process on port 8050 (PID: 25420)
#  Monitoring cleanup completed
#
#  Monitoring & Observability Pipeline Progress: [] 40.0%
#  Step 2/5: Performance Check
# ------------------------------------------------------------
#  Performance Health Check executed successfully
# 📤 Output: Collecting current metrics for health report...
#
# System Health Summary
# ==================================================
# Overall Status: WARNING
# Timestamp: 2025-06-23T15:51:17.094926
# Local Mode: True
# AWS Enabled: False
#
# System Health: HEALTHY
#   CPU: 0.3%
#   Memory: 1.6%
#   Disk: 0.0%
#   Memory Available: 488.0 GB
#   Disk Free: 37.0 GB
#
# API Health: UNHEALTHY
#   Models Loaded: 0
#   Uptime: 0.0 seconds
#   Response Time: 0.0 ms
#
# Model Health: HEALTHY
#   Total Models: 4
#   Healthy: 4
#   Warning: 0
#   Critical: 0
#
# Data Health: HEALTHY
#   Quality Score: 99.8%
#   Freshness: 0.2 hours
#   Validation: unknown
#
# Active Alerts: 0
#   Monitoring Uptime: 0.0 minutes
#
# Some issues detected, monitoring recommended
#
#
#  Monitoring & Observability Pipeline Progress: [] 60.0%
#  Step 3/5: Drift Analysis
# ------------------------------------------------------------
#  Drift Detection Analysis executed successfully
# 📤 Output: Data Drift Detection Starting
#    Method: statistical
#    Local mode: True
# Current data loaded: (6989, 105)
# Report generated: data/monitoring/reports/drift_report_20250623_155119.html
#
# Drift Detection Results:
# ==================================================
# Overall Drift Detected: True
# Drift Score: 0.2982
# Method: statistical
# Reference Data: [32616, 105]
# Current Data: [6989, 105]
#
# Summary:
# Features Analyzed: 98
# Drifted Features: 54
# Drift Ratio: 55.1%
# Threshold: 0.25
#
# Top Drifted Features:
#   Item Code: 1.5360
#   Date: 1.0265
#   Days_Since_Epoch: 1.0265
#   Avg_Quantity: 0.9766
#   Year: 0.8873
# Drift alert sent
#
# Drift detection operation completed successfully
#
#
#  Monitoring & Observability Pipeline Progress: [] 80.0%
#  Step 4/5: Performance Monitor
# ------------------------------------------------------------
#  Performance Monitor started (PID: 25539)
#
#  Monitoring & Observability Pipeline Progress: [] 100.0%
#  Step 5/5: Drift Monitor
# ------------------------------------------------------------
#  Drift Monitor started (PID: 25542)
#
#  Starting monitoring dashboard on port 8050...
#  Monitoring Dashboard started (PID: 25610)
#  Dashboard will be available at: http://localhost:8050
#
#  Monitoring & Observability Pipeline Progress: [] 100.0%
#  Step 5/5: Completed
# ------------------------------------------------------------
#
#  Monitoring & Observability Pipeline completed successfully!
#
#  ACTIVE MONITORING SERVICES:
#    •  Performance Monitor: Running
#    •  Drift Detection: Running
#    •  Dashboard: http://localhost:8050
#
#  MONITORING COMMANDS:
#    •  Check status: Run monitoring status check below
#    •  Stop services: Run monitoring cleanup below
#    •  View logs: Check data/monitoring/logs/
#
#  NEXT STEPS:
#    1.  Monitor dashboard for real-time metrics
#    2.  Configure alert thresholds
#    3.  Review performance trends
#    4.  Set up automated reporting
#
#  Monitoring pipeline execution completed successfully!

# %% [markdown]
# ## 8. Monitoring Status & Control Panel
#
# **Purpose**: Monitor and control all running services and processes.
#
# This section provides:
# - Real-time status of all monitoring services
# - Port usage and availability checking
# - Service control (start/stop/restart)
# - Log file access and viewing
# - Emergency shutdown capabilities

# %%
# Check current monitoring status
print(" MONITORING STATUS CHECK")
print("=" * 50)

monitoring_active = check_monitoring_status()

if monitoring_active:
    print("\n Monitoring services are running")
else:
    print("\n No monitoring services detected")
    print("💡 Run the monitoring pipeline above to start services")

# Service control options
print("\n SERVICE CONTROL OPTIONS:")
print("   1.  Status Check: Already completed above")
print("   2.  Stop Services: Run the cell below")
print("   3.  Restart Services: Stop then run monitoring pipeline")
print("   4.  View Logs: Check data/monitoring/logs/ directory")
# Out:
#  MONITORING STATUS CHECK
# ==================================================
#
#  MONITORING SYSTEM STATUS
# ==================================================
#  Found 3 monitoring processes:
#    • Performance: PID 25539
#    • Drift Detection: PID 25542
#    • Performance: PID 25610
#
#  Port Status:
#    • Port 8002: ⚪ Available
#    • Port 8050:  In Use
#    • Port 8051: ⚪ Available
#    • Port 8052: ⚪ Available
#
#  Monitoring services are running
#
#  SERVICE CONTROL OPTIONS:
#    1.  Status Check: Already completed above
#    2.  Stop Services: Run the cell below
#    3.  Restart Services: Stop then run monitoring pipeline
#    4.  View Logs: Check data/monitoring/logs/ directory

# %%
# EMERGENCY STOP - Run this cell to stop all monitoring services
stop_all_services = False  # Set to True to stop all services

if stop_all_services:
    print(" EMERGENCY STOP - Stopping all monitoring services...")
    stop_monitoring_processes()
    
    # Verify shutdown
    time.sleep(2)
    remaining_processes = check_monitoring_status()
    
    if not remaining_processes:
        print(" All monitoring services stopped successfully")
    else:
        print(" Some processes may still be running")
else:
    print(" Service stop skipped. Set stop_all_services=True to stop services.")
# Out:
#  Service stop skipped. Set stop_all_services=True to stop services.

# %% [markdown]
# ##  9. Testing & Quality Assurance Pipeline
#
# **Purpose**: Run comprehensive testing and quality checks on the codebase.
#
# This pipeline performs:
# 1. **Unit Tests**: Test individual components and functions
# 2. **Integration Tests**: Test component interactions
# 3. **Code Quality**: Linting, formatting, and style checks
# 4. **Security Scanning**: Vulnerability detection and dependency checks
# 5. **Coverage Analysis**: Test coverage reporting
#
# **Equivalent Makefile Commands**:
# - `make test-full`
# - `make quality-check`
# - `make security-check`
# - `make test-coverage`

# %%
def run_testing_pipeline(include_security=True, include_coverage=True):
    """
    Execute comprehensive testing and quality assurance pipeline
    
    Args:
        include_security: Whether to run security scans
        include_coverage: Whether to generate coverage reports
    """
    pipeline_name = "Testing & Quality Assurance Pipeline"
    total_steps = 5 if include_security and include_coverage else 3
    current_step = 0
    
    print(f"\n STARTING: {pipeline_name}")
    print("=" * 70)
    
    # Step 1: Code Formatting
    current_step += 1
    show_pipeline_status(pipeline_name, current_step, total_steps, "Code Formatting")
    
    # Black formatting
    success = run_pipeline_step(
        step_name="Black Code Formatting",
        command=['black', 'src/', 'tests/', '--line-length=100', '--check'],
        description="Check code formatting with Black"
    )
    
    if not success:
        print(" Code formatting issues found. Running auto-format...")
        run_pipeline_step(
            step_name="Auto-format with Black",
            command=['black', 'src/', 'tests/', '--line-length=100'],
            description="Auto-format code with Black"
        )
    
    # Import sorting
    run_pipeline_step(
        step_name="Import Sorting",
        command=['isort', 'src/', 'tests/', '--profile', 'black', '--check-only'],
        description="Check import sorting with isort"
    )
    
    # Step 2: Code Linting
    current_step += 1
    show_pipeline_status(pipeline_name, current_step, total_steps, "Code Linting")
    
    # Flake8 linting
    success = run_pipeline_step(
        step_name="Flake8 Linting",
        command=['flake8', 'src/', '--max-line-length=100', '--ignore=E203,W503'],
        description="Check code quality with Flake8"
    )
    
    # MyPy type checking (optional - may not be configured)
    mypy_success = run_pipeline_step(
        step_name="MyPy Type Checking",
        command=['mypy', 'src/', '--ignore-missing-imports'],
        description="Static type checking with MyPy"
    )
    
    if not mypy_success:
        print(" MyPy type checking found issues (non-blocking)")
    
    # Step 3: Unit and Integration Tests
    current_step += 1
    show_pipeline_status(pipeline_name, current_step, total_steps, "Test Execution")
    
    if include_coverage:
        # Run tests with coverage
        success = run_pipeline_step(
            step_name="Pytest with Coverage",
            command=[
                'python3', '-m', 'pytest', 'tests/',
                '--cov=src/',
                '--cov-report=html',
                '--cov-report=term-missing',
                '--cov-report=xml',
                '-v'
            ],
            description="Run tests with coverage analysis",
            check_files=['htmlcov/index.html', 'coverage.xml']
        )
    else:
        # Run tests without coverage
        success = run_pipeline_step(
            step_name="Pytest",
            command=['python3', '-m', 'pytest', 'tests/', '-v'],
            description="Run unit and integration tests"
        )
    
    if not success:
        print(" Test execution failed. Check test output for details.")
        return False
    
    if include_security:
        # Step 4: Security Scanning
        current_step += 1
        show_pipeline_status(pipeline_name, current_step, total_steps, "Security Scanning")
        
        # Bandit security scan
        bandit_success = run_pipeline_step(
            step_name="Bandit Security Scan",
            command=[
                'bandit', '-r', 'src/',
                '-f', 'json',
                '-o', 'security_report.json'
            ],
            description="Security vulnerability scanning with Bandit",
            check_files=['security_report.json']
        )
        
        # Safety dependency check
        safety_success = run_pipeline_step(
            step_name="Safety Dependency Check",
            command=['safety', 'check'],
            description="Check dependencies for known vulnerabilities"
        )
        
        if not bandit_success or not safety_success:
            print(" Security issues detected. Review security_report.json")
    
    # Final status
    current_step = total_steps
    show_pipeline_status(pipeline_name, current_step, total_steps, "Completed")
    
    print(f"\n {pipeline_name} completed!")
    
    # Summary
    print(f"\n QUALITY ASSURANCE SUMMARY:")
    print(f"   •  Code formatting checked")
    print(f"   •  Linting completed")
    print(f"   •  Tests executed")
    
    if include_coverage:
        print(f"   •  Coverage report: htmlcov/index.html")
    
    if include_security:
        print(f"   •  Security scan completed")
        print(f"   •  Security report: security_report.json")
    
    print("\n NEXT STEPS:")
    print("   1.  Review test coverage report")
    print("   2.  Address any security findings")
    print("   3.  Ready for deployment")
    
    return True

# Execute testing pipeline
print(" Ready to run testing and quality assurance pipeline...")
print("💡 This includes: formatting + linting + testing + security + coverage")
print("\n⚡ Configure testing options below:")

# Configuration
run_security_scan = True
generate_coverage = True
run_testing = True

if run_testing:
    testing_success = run_testing_pipeline(
        include_security=run_security_scan,
        include_coverage=generate_coverage
    )
    
    if testing_success:
        print("\n Testing pipeline execution completed successfully!")
    else:
        print("\n Testing pipeline execution failed. Check logs for details.")
else:
    print(" Testing pipeline execution skipped. Set run_testing=True to execute.")
# Out:
#  Ready to run testing and quality assurance pipeline...
# 💡 This includes: formatting + linting + testing + security + coverage
#
# ⚡ Configure testing options below:
#
#  STARTING: Testing & Quality Assurance Pipeline
# ======================================================================
#
#  Testing & Quality Assurance Pipeline Progress: [] 20.0%
#  Step 1/5: Code Formatting
# ------------------------------------------------------------
#
#  EXECUTING: Black Code Formatting
#  Description: Check code formatting with Black
#  Started at: 2025-06-23 15:55:57
# ------------------------------------------------------------
#  Black Code Formatting failed with exception: [Errno 2] No such file or directory: 'black'
#  Execution time: 0.00 seconds
#  Code formatting issues found. Running auto-format...
#
#  EXECUTING: Auto-format with Black
#  Description: Auto-format code with Black
#  Started at: 2025-06-23 15:55:57
# ------------------------------------------------------------
#  Auto-format with Black failed with exception: [Errno 2] No such file or directory: 'black'
#  Execution time: 0.00 seconds
#
#  EXECUTING: Import Sorting
#  Description: Check import sorting with isort
#  Started at: 2025-06-23 15:55:57
# ------------------------------------------------------------
#  Import Sorting failed with return code 1
#  Execution time: 0.23 seconds
#  Error output:
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/data_processing/data_validation.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/data_processing/feature_engineering.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/data_processing/feature_store_integration.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/training/train_model.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/deployment/deployment_verification.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/deployment/model_registry.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/deployment/sagemaker_deploy.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/inference/api.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/inference/predictor.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/monitoring/drift_detector.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/monitoring/performance_monitor.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/utils/test_data_generator.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/tests/conftest.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/tests/unit/test_data_processing.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/tests/unit/test_deployment.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/tests/unit/test_model_training.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/tests/unit/test_monitoring.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/tests/integration/test_data_pipeline.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/tests/integration/test_deployment_pipeline.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/tests/integration/test_end_to_end.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/tests/integration/test_training_pipeline.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/tests/.ipynb_checkpoints/conftest-checkpoint.py Imports are incorrectly sorted and/or formatted.
#
#
#  Testing & Quality Assurance Pipeline Progress: [] 40.0%
#  Step 2/5: Code Linting
# ------------------------------------------------------------
#
#  EXECUTING: Flake8 Linting
#  Description: Check code quality with Flake8
#  Started at: 2025-06-23 15:55:57
# ------------------------------------------------------------
#  Flake8 Linting failed with return code 1
#  Execution time: 0.30 seconds
#  Standard output:
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:15:1: F401 'pathlib.Path' imported but unused
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:16:1: F401 'typing.List' imported but unused
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:16:1: F401 'typing.Tuple' imported but unused
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:53:28: E128 continuation line under-indented for visual indent
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:231:31: E128 continuation line under-indented for visual indent
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:266:101: E501 line too long (104 > 100 characters)
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:309:101: E501 line too long (107 > 100 characters)
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:321:65: W504 line break after binary operator
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:322:32: E128 continuation line under-indented for visual indent
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:354:9: F841 local variable 'e' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:444:67: W504 line break after binary operator
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:488:21: E226 missing whitespace around arithmetic operator
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:490:14: E226 missing whitespace around arithmetic operator
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:505:11: W292 no newline at end of file
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:13:1: F401 'datetime.datetime' imported but unused
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:71:9: F841 local variable 'e' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:83:64: W504 line break after binary operator
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:136:101: E501 line too long (101 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:173:101: E501 line too long (148 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:174:101: E501 line too long (158 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:175:101: E501 line too long (144 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:178:101: E501 line too long (148 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:179:101: E501 line too long (158 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:182:101: E501 line too long (148 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:183:101: E501 line too long (148 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:187:101: E501 line too long (102 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:213:101: E501 line too long (117 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:371:13: F841 local variable 'e' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:541:9: F841 local variable 'e' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:548:101: E501 line too long (103 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:562:21: E226 missing whitespace around arithmetic operator
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:564:14: E226 missing whitespace around arithmetic operator
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:572:11: W292 no newline at end of file
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:15:1: F401 'datetime.timezone' imported but unused
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:16:1: F401 'typing.List' imported but unused
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:16:1: F401 'typing.Optional' imported but unused
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:19:1: F401 'numpy as np' imported but unused
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:42:101: E501 line too long (101 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:44:58: E128 continuation line under-indented for visual indent
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:131:9: F841 local variable 'e' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:184:41: E128 continuation line under-indented for visual indent
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:208:17: F841 local variable 'athena_type' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:211:17: F841 local variable 'escaped_name' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:211:101: E501 line too long (121 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:214:9: F841 local variable 'columns_ddl' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:250:9: F841 local variable 'e' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:269:17: F841 local variable 'error_msg' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:269:101: E501 line too long (106 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:292:13: F841 local variable 'e' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:347:21: F841 local variable 'data_prefix' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:358:17: F841 local variable 'e' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:445:9: F841 local variable 'e' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:498:17: F841 local variable 'e' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:505:101: E501 line too long (108 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:525:17: F841 local variable 'e' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:550:101: E501 line too long (109 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:557:101: E501 line too long (108 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:673:21: E226 missing whitespace around arithmetic operator
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:675:14: E226 missing whitespace around arithmetic operator
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:678:9: F841 local variable 'fs_results' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:695:17: F841 local variable 'status_icon' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:715:11: W292 no newline at end of file
# src/data_processing/data_validation.py:15:1: F401 'pathlib.Path' imported but unused
# src/data_processing/data_validation.py:16:1: F401 'typing.List' imported but unused
# src/data_processing/data_validation.py:16:1: F401 'typing.Tuple' imported but unused
# src/data_processing/data_validation.py:32:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:37:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:39:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:47:46: W291 trailing whitespace
# src/data_processing/data_validation.py:52:81: W291 trailing whitespace
# src/data_processing/data_validation.py:53:28: E128 continuation line under-indented for visual indent
# src/data_processing/data_validation.py:85:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:87:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:92:48: W291 trailing whitespace
# src/data_processing/data_validation.py:96:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:102:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:107:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:113:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:122:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:126:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:129:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:133:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:145:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:148:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:159:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:167:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:179:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:190:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:193:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:208:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:219:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:228:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:230:57: W291 trailing whitespace
# src/data_processing/data_validation.py:231:31: E128 continuation line under-indented for visual indent
# src/data_processing/data_validation.py:241:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:245:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:251:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:255:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:259:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:264:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:266:101: E501 line too long (104 > 100 characters)
# src/data_processing/data_validation.py:268:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:274:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:280:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:287:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:294:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:299:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:305:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:309:101: E501 line too long (107 > 100 characters)
# src/data_processing/data_validation.py:312:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:317:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:321:65: W504 line break after binary operator
# src/data_processing/data_validation.py:321:66: W291 trailing whitespace
# src/data_processing/data_validation.py:322:32: E128 continuation line under-indented for visual indent
# src/data_processing/data_validation.py:323:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:330:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:335:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:341:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:348:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:353:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:356:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:362:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:371:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:376:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:384:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:388:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:395:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:398:40: W291 trailing whitespace
# src/data_processing/data_validation.py:402:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:408:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:414:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:416:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:423:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:428:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:432:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:437:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:441:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:444:67: W504 line break after binary operator
# src/data_processing/data_validation.py:447:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:453:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:456:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:461:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:464:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:468:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:478:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:480:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:483:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:486:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:488:21: E226 missing whitespace around arithmetic operator
# src/data_processing/data_validation.py:490:14: E226 missing whitespace around arithmetic operator
# src/data_processing/data_validation.py:494:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:499:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:505:11: W292 no newline at end of file
# src/data_processing/feature_engineering.py:13:1: F401 'datetime.datetime' imported but unused
# src/data_processing/feature_engineering.py:30:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:39:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:41:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:48:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:56:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:64:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:70:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:74:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:80:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:83:64: W504 line break after binary operator
# src/data_processing/feature_engineering.py:83:65: W291 trailing whitespace
# src/data_processing/feature_engineering.py:86:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:88:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:95:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:101:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:104:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:110:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:117:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:126:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:134:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:136:101: E501 line too long (101 > 100 characters)
# src/data_processing/feature_engineering.py:138:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:143:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:147:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:153:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:156:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:161:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:167:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:170:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:173:101: E501 line too long (149 > 100 characters)
# src/data_processing/feature_engineering.py:174:101: E501 line too long (159 > 100 characters)
# src/data_processing/feature_engineering.py:175:101: E501 line too long (145 > 100 characters)
# src/data_processing/feature_engineering.py:176:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:178:101: E501 line too long (149 > 100 characters)
# src/data_processing/feature_engineering.py:179:101: E501 line too long (159 > 100 characters)
# src/data_processing/feature_engineering.py:180:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:182:101: E501 line too long (149 > 100 characters)
# src/data_processing/feature_engineering.py:183:101: E501 line too long (149 > 100 characters)
# src/data_processing/feature_engineering.py:184:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:187:101: E501 line too long (102 > 100 characters)
# src/data_processing/feature_engineering.py:190:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:197:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:202:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:206:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:210:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:213:101: E501 line too long (117 > 100 characters)
# src/data_processing/feature_engineering.py:214:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:220:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:227:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:234:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:239:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:242:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:247:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:251:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:256:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:262:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:269:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:278:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:282:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:289:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:295:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:299:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:305:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:310:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:316:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:320:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:324:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:332:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:339:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:343:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:346:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:355:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:364:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:374:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:380:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:390:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:397:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:403:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:411:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:419:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:425:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:429:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:432:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:435:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:438:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:442:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:446:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:450:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:454:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:457:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:460:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:463:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:466:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:469:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:472:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:477:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:481:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:488:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:491:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:495:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:499:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:503:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:508:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:525:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:531:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:538:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:540:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:548:101: E501 line too long (103 > 100 characters)
# src/data_processing/feature_engineering.py:552:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:554:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:557:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:560:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:562:21: E226 missing whitespace around arithmetic operator
# src/data_processing/feature_engineering.py:564:14: E226 missing whitespace around arithmetic operator
# src/data_processing/feature_engineering.py:567:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:572:11: W292 no newline at end of file
# src/data_processing/feature_store_integration.py:15:1: F401 'datetime.timezone' imported but unused
# src/data_processing/feature_store_integration.py:16:1: F401 'typing.List' imported but unused
# src/data_processing/feature_store_integration.py:16:1: F401 'typing.Optional' imported but unused
# src/data_processing/feature_store_integration.py:19:1: F401 'numpy as np' imported but unused
# src/data_processing/feature_store_integration.py:34:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:39:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:42:101: E501 line too long (101 > 100 characters)
# src/data_processing/feature_store_integration.py:43:92: W291 trailing whitespace
# src/data_processing/feature_store_integration.py:44:58: E128 continuation line under-indented for visual indent
# src/data_processing/feature_store_integration.py:48:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:58:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:75:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:79:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:82:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:85:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:88:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:93:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:102:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:118:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:121:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:123:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:138:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:140:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:149:71: W291 trailing whitespace
# src/data_processing/feature_store_integration.py:155:76: W291 trailing whitespace
# src/data_processing/feature_store_integration.py:164:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:166:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:169:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:171:39: W291 trailing whitespace
# src/data_processing/feature_store_integration.py:174:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:180:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:183:85: W291 trailing whitespace
# src/data_processing/feature_store_integration.py:184:41: E128 continuation line under-indented for visual indent
# src/data_processing/feature_store_integration.py:187:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:191:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:199:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:207:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:209:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:211:101: E501 line too long (122 > 100 characters)
# src/data_processing/feature_store_integration.py:213:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:215:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:219:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:230:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:240:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:243:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:247:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:249:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:257:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:262:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:264:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:269:101: E501 line too long (106 > 100 characters)
# src/data_processing/feature_store_integration.py:271:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:273:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:279:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:298:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:300:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:304:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:307:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:316:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:321:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:328:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:332:34: W291 trailing whitespace
# src/data_processing/feature_store_integration.py:337:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:340:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:349:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:351:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:357:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:362:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:368:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:382:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:394:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:398:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:409:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:413:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:441:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:444:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:452:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:459:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:463:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:467:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:471:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:475:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:478:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:484:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:489:39: W291 trailing whitespace
# src/data_processing/feature_store_integration.py:493:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:497:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:501:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:505:101: E501 line too long (108 > 100 characters)
# src/data_processing/feature_store_integration.py:514:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:524:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:528:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:530:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:534:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:540:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:544:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:550:101: E501 line too long (109 > 100 characters)
# src/data_processing/feature_store_integration.py:552:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:554:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:557:101: E501 line too long (108 > 100 characters)
# src/data_processing/feature_store_integration.py:560:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:566:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:572:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:575:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:580:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:583:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:587:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:590:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:598:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:606:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:611:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:616:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:621:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:623:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:628:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:641:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:643:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:646:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:664:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:671:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:673:21: E226 missing whitespace around arithmetic operator
# src/data_processing/feature_store_integration.py:675:14: E226 missing whitespace around arithmetic operator
# src/data_processing/feature_store_integration.py:676:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:679:15: F541 f-string is missing placeholders
# src/data_processing/feature_store_integration.py:685:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:688:15: F541 f-string is missing placeholders
# src/data_processing/feature_store_integration.py:691:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:693:19: F541 f-string is missing placeholders
# src/data_processing/feature_store_integration.py:697:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:701:19: F541 f-string is missing placeholders
# src/data_processing/feature_store_integration.py:702:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:704:1: W293 blank line contains whitespace
# src/data_processing/feature_store_integration.py:715:11: W292 no newline at end of file
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:14:1: F401 'time' imported but unused
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:16:1: F401 'typing.Tuple' imported but unused
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:19:1: F401 'pandas as pd' imported but unused
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:50:9: F841 local variable 'status_emoji' is assigned to but never used
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:69:101: E501 line too long (102 > 100 characters)
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:71:13: F841 local variable 'e' is assigned to but never used
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:79:13: F841 local variable 'e' is assigned to but never used
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:85:9: F841 local variable 'e' is assigned to but never used
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:97:17: F841 local variable 'role' is assigned to but never used
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:104:13: F841 local variable 'e' is assigned to but never used
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:114:101: E501 line too long (109 > 100 characters)
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:126:13: F841 local variable 'e' is assigned to but never used
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:131:9: F841 local variable 'e' is assigned to but never used
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:177:9: F841 local variable 'e' is assigned to but never used
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:210:9: F841 local variable 'e' is assigned to but never used
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:241:9: F841 local variable 'e' is assigned to but never used
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:262:101: E501 line too long (107 > 100 characters)
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:269:101: E501 line too long (102 > 100 characters)
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:284:9: F841 local variable 'e' is assigned to but never used
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:300:101: E501 line too long (105 > 100 characters)
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:322:9: F841 local variable 'e' is assigned to but never used
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:347:9: F841 local variable 'e' is assigned to but never used
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:364:101: E501 line too long (101 > 100 characters)
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:388:101: E501 line too long (104 > 100 characters)
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:399:18: E226 missing whitespace around arithmetic operator
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:401:18: E226 missing whitespace around arithmetic operator
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:432:17: F841 local variable 'endpoint_success' is assigned to but never used
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:441:25: E226 missing whitespace around arithmetic operator
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:443:18: E226 missing whitespace around arithmetic operator
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:472:24: E128 continuation line under-indented for visual indent
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:474:24: E128 continuation line under-indented for visual indent
# src/deployment/.ipynb_checkpoints/deployment_verification-checkpoint.py:499:11: W292 no newline at end of file
# src/deployment/.ipynb_checkpoints/model_registry-checkpoint.py:16:1: F401 'typing.Tuple' imported but unused
# src/deployment/.ipynb_checkpoints/model_registry-checkpoint.py:24:1: F401 'pandas as pd' imported but unused
# src/deployment/.ipynb_checkpoints/model_registry-checkpoint.py:26:1: F401 'mlflow.entities.ViewType' imported but unused
# src/deployment/.ipynb_checkpoints/model_registry-checkpoint.py:28:1: F401 'sklearn.metrics.mean_absolute_error' imported but unused
# src/deployment/.ipynb_checkpoints/model_registry-checkpoint.py:28:1: F401 'sklearn.metrics.mean_squared_error' imported but unused
# src/deployment/.ipynb_checkpoints/model_registry-checkpoint.py:28:1: F401 'sklearn.metrics.r2_score' imported but unused
# src/deployment/.ipynb_checkpoints/model_registry-checkpoint.py:62:13: F841 local variable 's3_bucket' is assigned to but never used
# ...
# src/training/train_model.py:310:1: W293 blank line contains whitespace
# src/training/train_model.py:318:1: W293 blank line contains whitespace
# src/training/train_model.py:329:1: W293 blank line contains whitespace
# src/training/train_model.py:332:1: W293 blank line contains whitespace
# src/training/train_model.py:336:21: E128 continuation line under-indented for visual indent
# src/training/train_model.py:340:1: W293 blank line contains whitespace
# src/training/train_model.py:346:34: W291 trailing whitespace
# src/training/train_model.py:353:29: W291 trailing whitespace
# src/training/train_model.py:358:1: W293 blank line contains whitespace
# src/training/train_model.py:360:1: W293 blank line contains whitespace
# src/training/train_model.py:365:1: W293 blank line contains whitespace
# src/training/train_model.py:372:1: W293 blank line contains whitespace
# src/training/train_model.py:375:1: W293 blank line contains whitespace
# src/training/train_model.py:379:1: W293 blank line contains whitespace
# src/training/train_model.py:385:1: W293 blank line contains whitespace
# src/training/train_model.py:389:1: W293 blank line contains whitespace
# src/training/train_model.py:391:1: W293 blank line contains whitespace
# src/training/train_model.py:395:1: W293 blank line contains whitespace
# src/training/train_model.py:398:1: W293 blank line contains whitespace
# src/training/train_model.py:407:1: W293 blank line contains whitespace
# src/training/train_model.py:414:1: W293 blank line contains whitespace
# src/training/train_model.py:418:1: W293 blank line contains whitespace
# src/training/train_model.py:423:1: W293 blank line contains whitespace
# src/training/train_model.py:428:26: E128 continuation line under-indented for visual indent
# src/training/train_model.py:430:1: W293 blank line contains whitespace
# src/training/train_model.py:434:1: W293 blank line contains whitespace
# src/training/train_model.py:438:1: W293 blank line contains whitespace
# src/training/train_model.py:446:1: W293 blank line contains whitespace
# src/training/train_model.py:455:1: W293 blank line contains whitespace
# src/training/train_model.py:462:1: W293 blank line contains whitespace
# src/training/train_model.py:464:1: W293 blank line contains whitespace
# src/training/train_model.py:469:1: W293 blank line contains whitespace
# src/training/train_model.py:472:1: W293 blank line contains whitespace
# src/training/train_model.py:475:1: W293 blank line contains whitespace
# src/training/train_model.py:484:1: W293 blank line contains whitespace
# src/training/train_model.py:488:1: W293 blank line contains whitespace
# src/training/train_model.py:495:1: W293 blank line contains whitespace
# src/training/train_model.py:498:1: W293 blank line contains whitespace
# src/training/train_model.py:504:1: W293 blank line contains whitespace
# src/training/train_model.py:508:1: W293 blank line contains whitespace
# src/training/train_model.py:513:1: W293 blank line contains whitespace
# src/training/train_model.py:517:79: W291 trailing whitespace
# src/training/train_model.py:518:28: E128 continuation line under-indented for visual indent
# src/training/train_model.py:522:1: W293 blank line contains whitespace
# src/training/train_model.py:524:1: W293 blank line contains whitespace
# src/training/train_model.py:528:1: W293 blank line contains whitespace
# src/training/train_model.py:537:1: W293 blank line contains whitespace
# src/training/train_model.py:544:101: E501 line too long (104 > 100 characters)
# src/training/train_model.py:546:1: W293 blank line contains whitespace
# src/training/train_model.py:551:1: W293 blank line contains whitespace
# src/training/train_model.py:555:1: W293 blank line contains whitespace
# src/training/train_model.py:558:1: W293 blank line contains whitespace
# src/training/train_model.py:563:1: W293 blank line contains whitespace
# src/training/train_model.py:568:1: W293 blank line contains whitespace
# src/training/train_model.py:569:101: E501 line too long (114 > 100 characters)
# src/training/train_model.py:570:1: W293 blank line contains whitespace
# src/training/train_model.py:579:101: E501 line too long (104 > 100 characters)
# src/training/train_model.py:582:1: W293 blank line contains whitespace
# src/training/train_model.py:588:1: W293 blank line contains whitespace
# src/training/train_model.py:602:1: W293 blank line contains whitespace
# src/training/train_model.py:608:1: W293 blank line contains whitespace
# src/training/train_model.py:612:70: W291 trailing whitespace
# src/training/train_model.py:613:29: E128 continuation line under-indented for visual indent
# src/training/train_model.py:615:32: E226 missing whitespace around arithmetic operator
# src/training/train_model.py:617:32: E226 missing whitespace around arithmetic operator
# src/training/train_model.py:618:1: W293 blank line contains whitespace
# src/training/train_model.py:628:1: W293 blank line contains whitespace
# src/training/train_model.py:633:1: W293 blank line contains whitespace
# src/training/train_model.py:636:1: W293 blank line contains whitespace
# src/training/train_model.py:641:1: W293 blank line contains whitespace
# src/training/train_model.py:647:1: W293 blank line contains whitespace
# src/training/train_model.py:650:1: W293 blank line contains whitespace
# src/training/train_model.py:654:1: W293 blank line contains whitespace
# src/training/train_model.py:658:1: W293 blank line contains whitespace
# src/training/train_model.py:674:1: W293 blank line contains whitespace
# src/training/train_model.py:679:1: W293 blank line contains whitespace
# src/training/train_model.py:686:1: W293 blank line contains whitespace
# src/training/train_model.py:689:101: E501 line too long (101 > 100 characters)
# src/training/train_model.py:691:101: E501 line too long (103 > 100 characters)
# src/training/train_model.py:692:1: W293 blank line contains whitespace
# src/training/train_model.py:699:1: W293 blank line contains whitespace
# src/training/train_model.py:700:36: E226 missing whitespace around arithmetic operator
# src/training/train_model.py:702:36: E226 missing whitespace around arithmetic operator
# src/training/train_model.py:703:1: W293 blank line contains whitespace
# src/training/train_model.py:709:1: W293 blank line contains whitespace
# src/training/train_model.py:721:1: W293 blank line contains whitespace
# src/training/train_model.py:723:1: W293 blank line contains whitespace
# src/training/train_model.py:726:1: W293 blank line contains whitespace
# src/training/train_model.py:730:1: W293 blank line contains whitespace
# src/training/train_model.py:733:1: W293 blank line contains whitespace
# src/training/train_model.py:736:28: W291 trailing whitespace
# src/training/train_model.py:737:30: W291 trailing whitespace
# src/training/train_model.py:740:1: W293 blank line contains whitespace
# src/training/train_model.py:742:25: E226 missing whitespace around arithmetic operator
# src/training/train_model.py:744:18: E226 missing whitespace around arithmetic operator
# src/training/train_model.py:749:1: W293 blank line contains whitespace
# src/training/train_model.py:751:19: F541 f-string is missing placeholders
# src/training/train_model.py:759:1: W293 blank line contains whitespace
# src/training/train_model.py:762:1: W293 blank line contains whitespace
# src/training/train_model.py:763:27: E226 missing whitespace around arithmetic operator
# src/training/train_model.py:765:27: E226 missing whitespace around arithmetic operator
# src/training/train_model.py:766:1: W293 blank line contains whitespace
# src/training/train_model.py:771:15: F541 f-string is missing placeholders
# src/training/train_model.py:776:11: W292 no newline at end of file
# src/utils/test_data_generator.py:11:1: F401 'pandas as pd' imported but unused
# src/utils/test_data_generator.py:13:1: F401 'datetime.timedelta' imported but unused
# src/utils/test_data_generator.py:20:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:26:72: W291 trailing whitespace
# src/utils/test_data_generator.py:29:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:54:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:57:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:65:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:87:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:95:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:117:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:125:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:147:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:155:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:177:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:185:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:207:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:215:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:237:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:245:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:267:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:275:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:279:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:289:101: E501 line too long (112 > 100 characters)
# src/utils/test_data_generator.py:301:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:303:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:307:69: W291 trailing whitespace
# src/utils/test_data_generator.py:310:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:312:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:316:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:325:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:327:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:331:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:371:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:378:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:382:47: E226 missing whitespace around arithmetic operator
# src/utils/test_data_generator.py:387:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:390:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:391:15: F541 f-string is missing placeholders
# src/utils/test_data_generator.py:394:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:396:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:415:67: W291 trailing whitespace
# src/utils/test_data_generator.py:421:101: E501 line too long (102 > 100 characters)
# src/utils/test_data_generator.py:424:101: E501 line too long (219 > 100 characters)
# src/utils/test_data_generator.py:426:101: E501 line too long (170 > 100 characters)
# src/utils/test_data_generator.py:427:101: E501 line too long (170 > 100 characters)
# src/utils/test_data_generator.py:428:101: E501 line too long (179 > 100 characters)
# src/utils/test_data_generator.py:430:101: E501 line too long (144 > 100 characters)
# src/utils/test_data_generator.py:433:101: E501 line too long (165 > 100 characters)
# src/utils/test_data_generator.py:434:101: E501 line too long (218 > 100 characters)
# src/utils/test_data_generator.py:437:101: E501 line too long (122 > 100 characters)
# src/utils/test_data_generator.py:439:101: E501 line too long (102 > 100 characters)
# src/utils/test_data_generator.py:443:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:447:15: F541 f-string is missing placeholders
# src/utils/test_data_generator.py:448:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:474:101: E501 line too long (138 > 100 characters)
# src/utils/test_data_generator.py:477:101: E501 line too long (138 > 100 characters)
# src/utils/test_data_generator.py:480:101: E501 line too long (148 > 100 characters)
# src/utils/test_data_generator.py:489:101: E501 line too long (131 > 100 characters)
# src/utils/test_data_generator.py:491:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:495:15: F541 f-string is missing placeholders
# src/utils/test_data_generator.py:507:101: E501 line too long (101 > 100 characters)
# src/utils/test_data_generator.py:511:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:512:64: W291 trailing whitespace
# src/utils/test_data_generator.py:513:24: E128 continuation line under-indented for visual indent
# src/utils/test_data_generator.py:514:38: W291 trailing whitespace
# src/utils/test_data_generator.py:515:24: E128 continuation line under-indented for visual indent
# src/utils/test_data_generator.py:515:96: W291 trailing whitespace
# src/utils/test_data_generator.py:516:32: E128 continuation line under-indented for visual indent
# src/utils/test_data_generator.py:516:98: W291 trailing whitespace
# src/utils/test_data_generator.py:517:32: E128 continuation line under-indented for visual indent
# src/utils/test_data_generator.py:518:24: E128 continuation line under-indented for visual indent
# src/utils/test_data_generator.py:519:61: W291 trailing whitespace
# src/utils/test_data_generator.py:520:24: E128 continuation line under-indented for visual indent
# src/utils/test_data_generator.py:522:24: E128 continuation line under-indented for visual indent
# src/utils/test_data_generator.py:523:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:525:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:528:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:530:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:535:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:536:15: F541 f-string is missing placeholders
# src/utils/test_data_generator.py:537:101: E501 line too long (156 > 100 characters)
# src/utils/test_data_generator.py:538:101: E501 line too long (156 > 100 characters)
# src/utils/test_data_generator.py:539:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:544:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:554:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:558:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:560:15: F541 f-string is missing placeholders
# src/utils/test_data_generator.py:561:101: E501 line too long (138 > 100 characters)
# src/utils/test_data_generator.py:562:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:563:11: F541 f-string is missing placeholders
# src/utils/test_data_generator.py:567:11: W292 no newline at end of file
#
#
#  EXECUTING: MyPy Type Checking
#  Description: Static type checking with MyPy
#  Started at: 2025-06-23 15:55:58
# ------------------------------------------------------------
#  MyPy Type Checking failed with exception: [Errno 2] No such file or directory: 'mypy'
#  Execution time: 0.00 seconds
#  MyPy type checking found issues (non-blocking)
#
#  Testing & Quality Assurance Pipeline Progress: [] 60.0%
#  Step 3/5: Test Execution
# ------------------------------------------------------------
#
#  EXECUTING: Pytest with Coverage
#  Description: Run tests with coverage analysis
#  Started at: 2025-06-23 15:55:58
# ------------------------------------------------------------
#  Pytest with Coverage failed with return code 4
#  Execution time: 1.75 seconds
#  Error output:
# ImportError while loading conftest '/home/sagemaker-user/demand-stock-forecasting-mlops/tests/conftest.py'.
# tests/conftest.py:22: in <module>
#     from moto import mock_s3, mock_sagemaker, mock_athena
# E   ModuleNotFoundError: No module named 'moto'
#
#  Test execution failed. Check test output for details.
#
#  Testing pipeline execution failed. Check logs for details.

# %% [markdown]
# ##  10. Master Workflow Orchestrator
#
# **Purpose**: Execute complete end-to-end MLOps workflows with a single command.
#
# This section provides pre-configured workflows for different scenarios:
#
# ###  Available Workflows:
#
# 1. **Development Workflow**: Data pipeline → Training → Testing → Dev deployment
# 2. **Staging Workflow**: Complete pipeline → Staging deployment → Monitoring
# 3. **Production Workflow**: Full validation → Production deployment → Full monitoring
# 4. **CI/CD Simulation**: Testing → Quality checks → Deployment pipeline
# 5. **Complete MLOps**: Everything - data to production with monitoring
#
# **Equivalent Makefile Commands**:
# - `make workflow-dev`
# - `make workflow-staging`
# - `make workflow-prod`
# - `make pipeline-full`
# - `make pipeline-production`

# %%
def run_development_workflow():
    """
    Complete development workflow: data → training → testing → dev deployment
    """
    workflow_name = "Development Workflow"
    print(f"\n STARTING: {workflow_name}")
    print("=" * 70)
    print(" Pipeline: Data → Training → Testing → Dev Deployment")
    
    # Phase 1: Data Pipeline
    print("\n Phase 1: Data Pipeline")
    if not run_data_pipeline_full(include_bi=False):
        print(" Development workflow failed at data pipeline")
        return False
    
    # Phase 2: Model Training
    print("\n Phase 2: Model Training")
    if not run_training_pipeline():
        print(" Development workflow failed at training")
        return False
    
    # Phase 3: Fast Testing
    print("\n Phase 3: Fast Testing")
    if not run_testing_pipeline(include_security=False, include_coverage=False):
        print(" Development workflow failed at testing")
        return False
    
    # Phase 4: Dev Deployment
    print("\n Phase 4: Development Deployment")
    if not deploy_to_environment('dev', test_endpoint=True):
        print(" Development workflow failed at deployment")
        return False
    
    print(f"\n {workflow_name} completed successfully!")
    return True

def run_staging_workflow():
    """
    Complete staging workflow: full pipeline → staging deployment → monitoring
    """
    workflow_name = "Staging Workflow"
    print(f"\n STARTING: {workflow_name}")
    print("=" * 70)
    print(" Pipeline: Full Data + Training → Staging → Monitoring")
    
    # Phase 1: Complete Data + Training Pipeline
    print("\n Phase 1: Complete Data Pipeline")
    if not run_data_pipeline_full(include_bi=True):
        print(" Staging workflow failed at data pipeline")
        return False
    
    print("\n Phase 2: Model Training & Registry")
    if not run_training_pipeline():
        print(" Staging workflow failed at training")
        return False
    
    # Phase 2: Staging Deployment
    print("\n Phase 3: Staging Deployment")
    if not deploy_to_environment('staging', test_endpoint=True):
        print(" Staging workflow failed at deployment")
        return False
    
    # Phase 3: Start Monitoring
    print("\n Phase 4: Monitoring Setup")
    if not run_monitoring_pipeline(start_services=True, run_drift_analysis=True):
        print(" Monitoring setup failed, but deployment succeeded")
    
    print(f"\n {workflow_name} completed successfully!")
    return True

def run_production_workflow():
    """
    Complete production workflow: full validation → production → comprehensive monitoring
    """
    workflow_name = "Production Workflow"
    print(f"\n STARTING: {workflow_name}")
    print("=" * 70)
    print(" Pipeline: Full Validation → Production → Comprehensive Monitoring")
    
    # Phase 1: Full Testing & Quality
    print("\n Phase 1: Comprehensive Testing")
    if not run_testing_pipeline(include_security=True, include_coverage=True):
        print(" Production workflow failed at testing")
        return False
    
    # Phase 2: Production Deployment
    print("\n Phase 2: Production Deployment")
    if not deploy_to_environment('prod', test_endpoint=True):
        print(" Production workflow failed at deployment")
        return False
    
    # Phase 3: Comprehensive Monitoring
    print("\n Phase 3: Production Monitoring")
    if not run_monitoring_pipeline(start_services=True, run_drift_analysis=True):
        print(" Monitoring setup failed, but deployment succeeded")
    
    print(f"\n {workflow_name} completed successfully!")
    print("\n Your model is now live in production with full monitoring!")
    return True

def run_complete_mlops_pipeline():
    """
    Complete end-to-end MLOps pipeline: everything from data to production
    """
    workflow_name = "Complete MLOps Pipeline"
    print(f"\n STARTING: {workflow_name}")
    print("=" * 70)
    print(" End-to-End: Data → Training → Testing → Multi-Env Deployment → Monitoring")
    print(" This will take 30-60 minutes to complete")
    
    start_time = time.time()
    
    # Phase 1: Complete Data Pipeline
    print("\n Phase 1: Complete Data Pipeline")
    if not run_data_pipeline_full(include_bi=True):
        print(" Complete MLOps pipeline failed at data phase")
        return False
    
    # Phase 2: Model Training & Registry
    print("\n Phase 2: Model Training & Registry")
    if not run_training_pipeline():
        print(" Complete MLOps pipeline failed at training phase")
        return False
    
    # Phase 3: Quality Assurance
    print("\n Phase 3: Quality Assurance")
    if not run_testing_pipeline(include_security=True, include_coverage=True):
        print(" Complete MLOps pipeline failed at testing phase")
        return False
    
    # Phase 4: Multi-Environment Deployment
    print("\n Phase 4: Multi-Environment Deployment")
    if not run_complete_deployment_workflow():
        print(" Complete MLOps pipeline failed at deployment phase")
        return False
    
    # Phase 5: Production Monitoring
    print("\n Phase 5: Production Monitoring")
    if not run_monitoring_pipeline(start_services=True, run_drift_analysis=True):
        print(" Monitoring setup failed, but deployment succeeded")
    
    # Final summary
    execution_time = (time.time() - start_time) / 60
    
    print(f"\n {workflow_name} completed successfully!")
    print(f" Total execution time: {execution_time:.1f} minutes")
    
    print("\n DEPLOYMENT SUMMARY:")
    print("   •  Data pipeline with Feature Store and Athena")
    print("   •  Trained models registered in Model Registry")
    print("   •  Full test suite with security and coverage")
    print("   •  Multi-environment deployment (dev/staging/prod)")
    print("   •  Real-time monitoring and drift detection")
    
    print("\n Your complete MLOps pipeline is now operational!")
    return True

# Workflow Selection Interface
print(" MASTER WORKFLOW ORCHESTRATOR")
print("=" * 50)
print("\n Available Workflows:")
print("   1.  Development: Fast iteration workflow")
print("   2.  Staging: Complete pipeline with staging deployment")
print("   3.  Production: Full validation with production deployment")
print("   4.  Complete MLOps: End-to-end everything (30-60 min)")

# Configuration - Choose your workflow
selected_workflow = "development"  # Options: "development", "staging", "production", "complete"
run_workflow = True               # Set to True to execute

print(f"\n⚡ Selected workflow: {selected_workflow}")
print(f" Execution: {'ENABLED' if run_workflow else 'DISABLED'}")

if run_workflow:
    workflow_success = False
    
    if selected_workflow == "development":
        workflow_success = run_development_workflow()
    elif selected_workflow == "staging":
        workflow_success = run_staging_workflow()
    elif selected_workflow == "production":
        workflow_success = run_production_workflow()
    elif selected_workflow == "complete":
        workflow_success = run_complete_mlops_pipeline()
    else:
        print(f" Unknown workflow: {selected_workflow}")
        print("Available options: development, staging, production, complete")
    
    if workflow_success:
        print("\n Master workflow execution completed successfully!")
        print(" Your MLOps pipeline is ready!")
    else:
        print("\n Master workflow execution failed. Check logs for details.")
else:
    print("\n Workflow execution skipped. Set run_workflow=True to execute.")
    print(" Choose your workflow by setting selected_workflow variable")
# Out:
#  MASTER WORKFLOW ORCHESTRATOR
# ==================================================
#
#  Available Workflows:
#    1.  Development: Fast iteration workflow
#    2.  Staging: Complete pipeline with staging deployment
#    3.  Production: Full validation with production deployment
#    4.  Complete MLOps: End-to-end everything (30-60 min)
#
# ⚡ Selected workflow: development
#  Execution: ENABLED
#
#  STARTING: Development Workflow
# ======================================================================
#  Pipeline: Data → Training → Testing → Dev Deployment
#
#  Phase 1: Data Pipeline
#
#  STARTING: Complete Data Pipeline
# ======================================================================
#  Creating project directories...
#     data/raw
#     data/processed
#     data/validation
#     data/monitoring/logs
#     data/monitoring/reports
#     data/monitoring/metrics
#     models
#     reports
#  All directories created successfully!
#
#  Complete Data Pipeline Progress: [] 25.0%
#  Step 1/4: Data Validation
# ------------------------------------------------------------
#
#  EXECUTING: Python Script: data_validation.py
#  Description: Validate data quality, schema, and consistency
#  Started at: 2025-06-23 15:59:14
# ------------------------------------------------------------
#  Python Script: data_validation.py completed successfully
#  Execution time: 1.82 seconds
#  Output:
#
# ============================================================
# DATA VALIDATION SUMMARY
# ============================================================
# Files Validated: 4
# Overall Quality Score: 97.49/100
# Validation Status: PASSED
#
#
#  Complete Data Pipeline Progress: [] 50.0%
#  Step 2/4: Feature Engineering
# ------------------------------------------------------------
#
#  EXECUTING: Python Script: feature_engineering.py
#  Description: Generate ML-ready features with time series components
#  Started at: 2025-06-23 15:59:16
# ------------------------------------------------------------
#  Python Script: feature_engineering.py completed successfully
#  Execution time: 8.83 seconds
#  Output:
#
# ============================================================
# FEATURE ENGINEERING SUMMARY
# ============================================================
# train: data/processed/train.parquet
# validation: data/processed/validation.parquet
# test: data/processed/test.parquet
# features_complete: data/processed/features_complete.parquet
# metadata: data/processed/feature_metadata.json
#
# Feature engineering completed successfully!
#
#
#  Complete Data Pipeline Progress: [] 75.0%
#  Step 3/4: Infrastructure Setup
# ------------------------------------------------------------
#
#  EXECUTING: Python Script: feature_store_integration.py
#  Description: Setup SageMaker Feature Store and Athena tables
#  Started at: 2025-06-23 15:59:25
# ------------------------------------------------------------
#  Python Script: feature_store_integration.py completed successfully
#  Execution time: 56.59 seconds
#  Output:
#
# ============================================================
# FINAL FIXED FEATURE STORE INTEGRATION SUMMARY
# ============================================================
# Feature Store:
#   Feature Group: demand-stock-forecasting-mlops-features-complete
#   Feature Group ARN: arn:aws:sagemaker:us-east-1:346761359662:feature-group/demand-stock-forecasting-mlops-features-complete
#   Total Features: 103
#   Sample Records: 10
#   Database: demand_stock_forecasting_mlops_feature_store
#
# Athena Integration:
#   Database Created: True
#   S3 Reorganized: True
#   Tables Created:
#     ✓ features_complete
#     ✓ train_data
#     ✓ validation_data
#     ✓ test_data
#    Test Query: SUCCESS (46595 records)
#
# Integration completed!
#
#  Your Athena integration is working!
#  Run: python3 scripts/run_sample_queries.py
#
#
#  Complete Data Pipeline Progress: [] 100.0%
#  Step 4/4: Athena Verification
# ------------------------------------------------------------
#  Athena verification completed
#  Query ID: 7081be95-0e17-4ab4-b607-06016323f28f
#
#  Complete Data Pipeline Progress: [] 100.0%
#  Step 4/4: Completed
# ------------------------------------------------------------
#
#  Complete Data Pipeline completed successfully!
#
#  NEXT STEPS:
#    1.  Open AWS Athena Console
#    2.  Select 'demand_stock_forecasting_mlops_feature_store' database
#    3.  Run: SHOW TABLES
#    4.  Query features: SELECT * FROM features_complete LIMIT 10
#    5.  Ready for model training!
#
#  Phase 2: Model Training
#
#  STARTING: Model Training & Registry Pipeline
# ======================================================================
#  Model Version: v20250623_160021
#
#  Model Training & Registry Pipeline Progress: [] 25.0%
#  Step 1/4: Model Training
# ------------------------------------------------------------
#
#  EXECUTING: Python Script: train_model.py
#  Description: Train forecasting models with evaluation
#  Started at: 2025-06-23 16:00:21
# ------------------------------------------------------------
#  Python Script: train_model.py completed successfully
#  Execution time: 100.68 seconds
#  Output:
# 2025-06-23 16:00:22,513 - ModelTrainer - INFO - ============================================================
# 2025-06-23 16:00:22,513 - ModelTrainer - INFO - LOGGING SETUP COMPLETED
# 2025-06-23 16:00:22,513 - ModelTrainer - INFO - ============================================================
# 2025-06-23 16:00:22,513 - ModelTrainer - INFO - Model Version: v20250623_160021
# 2025-06-23 16:00:22,513 - ModelTrainer - INFO - Detailed Log: logs/training_v20250623_160021_20250623_160022.log
# 2025-06-23 16:00:22,513 - ModelTrainer - INFO - Summary Log: logs/training_summary_v20250623_160021_20250623_160022.log
# 2025-06-23 16:00:22,513 - ModelTrainer - INFO - Log Directory: /home/sagemaker-user/demand-stock-forecasting-mlops/logs
# 2025-06-23 16:00:22,513 - ModelTrainer - INFO - ============================================================
# 2025-06-23 16:00:22,528 - ModelTrainer - INFO - ModelTrainer initialized with version: v20250623_160021
# 2025-06-23 16:00:22,528 - ModelTrainer - WARNING - ============================================================
# 2025-06-23 16:00:22,528 - ModelTrainer - WARNING - STARTING COMPLETE TRAINING PIPELINE
# 2025-06-23 16:00:22,528 - ModelTrainer - WARNING - ============================================================
# 2025-06-23 16:00:22,528 - ModelTrainer - INFO - Step 1: Loading processed data...
# 2025-06-23 16:00:22,528 - ModelTrainer - INFO - Loading processed feature data...
# 2025-06-23 16:00:22,579 - ModelTrainer - INFO - Loaded training data: (32616, 105)
# 2025-06-23 16:00:22,587 - ModelTrainer - INFO - Loaded validation data: (6989, 105)
# 2025-06-23 16:00:22,595 - ModelTrainer - INFO - Loaded test data: (6990, 105)
# 2025-06-23 16:00:22,608 - ModelTrainer - INFO - Step 2: Preparing features and targets...
# 2025-06-23 16:00:22,608 - ModelTrainer - INFO - Preparing features for 1-day forecast...
# 2025-06-23 16:00:22,833 - ModelTrainer - INFO - Features prepared: (32616, 90), Target: (32616,)
# 2025-06-23 16:00:22,833 - ModelTrainer - INFO - Feature columns: 90
# 2025-06-23 16:00:22,833 - ModelTrainer - WARNING - FEATURE PREPARATION COMPLETED - 90 features ready
# 2025-06-23 16:00:22,833 - ModelTrainer - INFO - Preparing features for 1-day forecast...
# 2025-06-23 16:00:22,895 - ModelTrainer - INFO - Features prepared: (6989, 90), Target: (6989,)
# 2025-06-23 16:00:22,895 - ModelTrainer - INFO - Feature columns: 90
# 2025-06-23 16:00:22,895 - ModelTrainer - WARNING - FEATURE PREPARATION COMPLETED - 90 features ready
# 2025-06-23 16:00:22,895 - ModelTrainer - INFO - Preparing features for 1-day forecast...
# 2025-06-23 16:00:22,957 - ModelTrainer - INFO - Features prepared: (6990, 90), Target: (6990,)
# 2025-06-23 16:00:22,957 - ModelTrainer - INFO - Feature columns: 90
# 2025-06-23 16:00:22,957 - ModelTrainer - WARNING - FEATURE PREPARATION COMPLETED - 90 features ready
# 2025-06-23 16:00:22,957 - ModelTrainer - INFO - Step 3: Training models...
# 2025-06-23 16:00:22,957 - ModelTrainer - WARNING - STARTING MODEL TRAINING PHASE
# 2025-06-23 16:00:22,957 - ModelTrainer - INFO - Training models...
# 2025-06-23 16:00:22,957 - ModelTrainer - WARNING - TRAINING LINEAR_REGRESSION...
# 2025-06-23 16:00:22,957 - ModelTrainer - INFO - Scaling features for linear_regression
# 2025-06-23 16:00:23,184 - ModelTrainer - INFO - linear_regression training completed in 0.23 seconds
# 2025-06-23 16:00:23,189 - ModelTrainer - WARNING - linear_regression - Validation MAPE: 11.701%
# 2025-06-23 16:00:23,189 - ModelTrainer - INFO - linear_regression - Validation RMSE: 1.335
# 2025-06-23 16:00:23,189 - ModelTrainer - INFO - linear_regression - Validation R²: 0.950
# 2025-06-23 16:00:23,189 - ModelTrainer - WARNING - TRAINING RIDGE...
# 2025-06-23 16:00:23,189 - ModelTrainer - INFO - Scaling features for ridge
# 2025-06-23 16:00:23,346 - ModelTrainer - INFO - ridge training completed in 0.16 seconds
# 2025-06-23 16:00:23,350 - ModelTrainer - WARNING - ridge - Validation MAPE: 11.692%
# 2025-06-23 16:00:23,350 - ModelTrainer - INFO - ridge - Validation RMSE: 1.335
# 2025-06-23 16:00:23,350 - ModelTrainer - INFO - ridge - Validation R²: 0.950
# 2025-06-23 16:00:23,350 - ModelTrainer - WARNING - TRAINING RANDOM_FOREST...
# 2025-06-23 16:00:26,465 - ModelTrainer - INFO - random_forest training completed in 3.12 seconds
# 2025-06-23 16:00:26,550 - ModelTrainer - WARNING - random_forest - Validation MAPE: 11.694%
# 2025-06-23 16:00:26,550 - ModelTrainer - INFO - random_forest - Validation RMSE: 1.450
# 2025-06-23 16:00:26,550 - ModelTrainer - INFO - random_forest - Validation R²: 0.941
# 2025-06-23 16:00:26,550 - ModelTrainer - WARNING - TRAINING GRADIENT_BOOSTING...
# 2025-06-23 16:02:02,266 - ModelTrainer - INFO - gradient_boosting training completed in 95.72 seconds
# 2025-06-23 16:02:02,270 - ModelTrainer - WARNING - gradient_boosting - Validation MAPE: 11.878%
# 2025-06-23 16:02:02,271 - ModelTrainer - INFO - gradient_boosting - Validation RMSE: 1.444
# 2025-06-23 16:02:02,271 - ModelTrainer - INFO - gradient_boosting - Validation R²: 0.941
# 2025-06-23 16:02:02,271 - ModelTrainer - WARNING - MODEL TRAINING PHASE COMPLETED
# 2025-06-23 16:02:02,271 - ModelTrainer - INFO - Step 4: Evaluating on test set...
# 2025-06-23 16:02:02,272 - ModelTrainer - WARNING - STARTING TEST SET EVALUATION
# 2025-06-23 16:02:02,272 - ModelTrainer - INFO - Evaluating models on test set...
# 2025-06-23 16:02:02,272 - ModelTrainer - INFO - Evaluating linear_regression on test set...
# 2025-06-23 16:02:02,293 - ModelTrainer - WARNING - linear_regression - Test MAPE: 7.048%
# 2025-06-23 16:02:02,293 - ModelTrainer - INFO - linear_regression - Test RMSE: 2.031
# 2025-06-23 16:02:02,293 - ModelTrainer - INFO - linear_regression - Test R²: 0.919
# 2025-06-23 16:02:02,293 - ModelTrainer - INFO - Evaluating ridge on test set...
# 2025-06-23 16:02:02,313 - ModelTrainer - WARNING - ridge - Test MAPE: 7.042%
# 2025-06-23 16:02:02,313 - ModelTrainer - INFO - ridge - Test RMSE: 2.031
# 2025-06-23 16:02:02,313 - ModelTrainer - INFO - ridge - Test R²: 0.919
# 2025-06-23 16:02:02,313 - ModelTrainer - INFO - Evaluating random_forest on test set...
# 2025-06-23 16:02:02,353 - ModelTrainer - WARNING - random_forest - Test MAPE: 7.096%
# 2025-06-23 16:02:02,353 - ModelTrainer - INFO - random_forest - Test RMSE: 1.883
# 2025-06-23 16:02:02,353 - ModelTrainer - INFO - random_forest - Test R²: 0.931
# 2025-06-23 16:02:02,353 - ModelTrainer - INFO - Evaluating gradient_boosting on test set...
# 2025-06-23 16:02:02,373 - ModelTrainer - WARNING - gradient_boosting - Test MAPE: 8.037%
# 2025-06-23 16:02:02,373 - ModelTrainer - INFO - gradient_boosting - Test RMSE: 1.885
# 2025-06-23 16:02:02,373 - ModelTrainer - INFO - gradient_boosting - Test R²: 0.931
# 2025-06-23 16:02:02,373 - ModelTrainer - WARNING - TEST SET EVALUATION COMPLETED
# 2025-06-23 16:02:02,373 - ModelTrainer - INFO - Step 5: Selecting best model...
# 2025-06-23 16:02:02,373 - ModelTrainer - WARNING - BEST MODEL SELECTED: ridge (MAPE: 11.692%)
# 2025-06-23 16:02:02,373 - ModelTrainer - INFO - Step 6: Saving models and results...
# 2025-06-23 16:02:02,373 - ModelTrainer - WARNING - SAVING MODELS AND RESULTS
# 2025-06-23 16:02:02,373 - ModelTrainer - INFO - Saving models and results...
# 2025-06-23 16:02:02,374 - ModelTrainer - INFO - Saved linear_regression model (0.01 MB)
# 2025-06-23 16:02:02,375 - ModelTrainer - INFO - Saved ridge model (0.01 MB)
# 2025-06-23 16:02:02,397 - ModelTrainer - INFO - Saved random_forest model (4.90 MB)
# 2025-06-23 16:02:02,400 - ModelTrainer - INFO - Saved gradient_boosting model (0.71 MB)
# 2025-06-23 16:02:02,400 - ModelTrainer - WARNING - BEST MODEL SAVED: ridge -> best_model.pkl (MAPE: 11.692%)
# 2025-06-23 16:02:02,400 - ModelTrainer - INFO - Saved evaluation results: models/evaluation.json
# 2025-06-23 16:02:02,400 - ModelTrainer - INFO - Saved feature info: models/feature_info.json
# 2025-06-23 16:02:02,401 - ModelTrainer - WARNING - SAVED 7 FILES TO models/
# 2025-06-23 16:02:02,401 - ModelTrainer - WARNING - ============================================================
# 2025-06-23 16:02:02,401 - ModelTrainer - WARNING - TRAINING PIPELINE COMPLETED SUCCESSFULLY!
# 2025-06-23 16:02:02,401 - ModelTrainer - WARNING - ============================================================
#
# ============================================================
# MODEL TRAINING SUMMARY
# ============================================================
# Model Version: v20250623_160021
# Status: SUCCESS
# Models Trained: 4
# Best Model: ridge
#
# Best Model Performance:
#   train_mae: 0.506
#   train_mse: 1.990
#   train_rmse: 1.411
#   train_r2: 0.964
#   train_mape: 5.326%
#   val_mae: 0.682
#   val_mse: 1.782
#   val_rmse: 1.335
#   val_r2: 0.950
#   val_mape: 11.692%
#   val_smape: 10.632%
#   test_mae: 0.508
#   test_rmse: 2.031
#   test_r2: 0.919
#   test_mape: 7.042%
#
# Output Path: models/
# Log Files: logs/training_v20250623_160021_*.log
# 2025-06-23 16:02:02,402 - ModelTrainer - WARNING - ============================================================
# 2025-06-23 16:02:02,402 - ModelTrainer - WARNING - MAIN FUNCTION COMPLETED SUCCESSFULLY
# 2025-06-23 16:02:02,402 - ModelTrainer - WARNING - ============================================================
#
#
#  Model Training & Registry Pipeline Progress: [] 50.0%
#  Step 2/4: Model Verification
# ------------------------------------------------------------
# 🔍 Verifying model artifacts:
#     best_model.pkl (5,713 bytes)
#     evaluation.json (2,263 bytes)
#
#  Model Performance Metrics:
#    • linear_regression: {'train_mae': 0.5056392079113663, 'train_mse': 1.9901760680814276, 'train_rmse': 1.4107360022631548, 'train_r2': 0.9638075015862446, 'train_mape': 5.326947686158999, 'val_mae': 0.6822868409481369, 'val_mse': 1.782934245278001, 'val_rmse': 1.3352656085131531, 'val_r2': 0.9497227795058321, 'val_mape': 11.700506739624721, 'val_smape': 10.638298186022938, 'test_mae': 0.5081868771827537, 'test_rmse': 2.0306325693299363, 'test_r2': 0.9193960002380387, 'test_mape': 7.047639291529275}
#    • ridge: {'train_mae': 0.5055338660970473, 'train_mse': 1.990184858148421, 'train_rmse': 1.4107391176785384, 'train_r2': 0.9638073417338121, 'train_mape': 5.325620147346603, 'val_mae': 0.6820620062017853, 'val_mse': 1.7822698839782376, 'val_rmse': 1.3350168103729023, 'val_r2': 0.9497415139261532, 'val_mape': 11.692430365041805, 'val_smape': 10.631585432941227, 'test_mae': 0.5079574189347851, 'test_rmse': 2.030536284385137, 'test_r2': 0.9194036439327055, 'test_mape': 7.0419568095491964}
#    • random_forest: {'train_mae': 0.35785821509286253, 'train_mse': 0.8691574675887455, 'train_rmse': 0.9322861511299766, 'train_r2': 0.9841938706974129, 'train_mape': 3.957731546751506, 'val_mae': 0.6855342038201652, 'val_mse': 2.1034750889388487, 'val_rmse': 1.4503361985894334, 'val_r2': 0.9406838019233412, 'val_mape': 11.693978746604545, 'val_smape': 10.5738990422777, 'test_mae': 0.5187141991497498, 'test_rmse': 1.882703232269873, 'test_r2': 0.9307120624147823, 'test_mape': 7.096184142545341}
#    • gradient_boosting: {'train_mae': 0.3571261693633963, 'train_mse': 0.62361417201593, 'train_rmse': 0.7896924540705261, 'train_r2': 0.9886592169941828, 'train_mape': 4.20273825705328, 'val_mae': 0.7012849969372428, 'val_mse': 2.0863257897146914, 'val_rmse': 1.4444119182957096, 'val_r2': 0.9411673974909831, 'val_mape': 11.877940892027047, 'val_smape': 10.652631174154257, 'test_mae': 0.5632813084316265, 'test_rmse': 1.8845635880975533, 'test_r2': 0.9305750637616115, 'test_mape': 8.037326720105682}
#
#  Model Training & Registry Pipeline Progress: [] 75.0%
#  Step 3/4: Model Registration
# ------------------------------------------------------------
#
#  EXECUTING: Python Script: model_registry.py
#  Description: Register trained models to SageMaker Model Registry
#  Started at: 2025-06-23 16:02:02
# ------------------------------------------------------------
#  Python Script: model_registry.py completed successfully
#  Execution time: 14.34 seconds
#  Output:
#
# ============================================================
# MODEL REGISTRATION RESULTS
# ============================================================
# linear_regression: registered
#   Run ID: 07b396faf06749508b5a75f82aa26152
# ridge: registered
#   Run ID: e46a5df1b32f437bb085581de609fd47
# random_forest: registered
#   Run ID: 1e84159b74c9471f921d2c907af7ce01
# gradient_boosting: registered
#   Run ID: cd5c9f286b014d9ba0e79edf176678e5
#
#
#  Model Training & Registry Pipeline Progress: [] 100.0%
#  Step 4/4: Registry Verification
# ------------------------------------------------------------
#
#  EXECUTING: Python Script: model_registry.py
#  Description: List all registered model versions
#  Started at: 2025-06-23 16:02:16
# ------------------------------------------------------------
#  Python Script: model_registry.py failed with return code 1
#  Execution time: 4.28 seconds
#  Error output:
# 2025-06-23 16:02:18.498461: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-23 16:02:18.526171: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-23 16:02:20,507 - model_registry - ERROR - Error setting up MLflow:  Model registry functionality is unavailable; got unsupported URI 's3://sagemaker-us-east-1-346761359662/mlflow' for model registry data storage. Supported URI schemes are: ['', 'file', 'databricks', 'databricks-uc', 'uc', 'http', 'https', 'postgresql', 'mysql', 'sqlite', 'mssql', 'arn']. See https://www.mlflow.org/docs/latest/tracking.html#storage for how to run an MLflow server against one of the supported backend storage locations.
# 2025-06-23 16:02:20,513 - model_registry - WARNING - Using local MLflow tracking as fallback
# 2025-06-23 16:02:20,513 - model_registry - INFO - Model Registry initialized successfully
#
#  Standard output:
# Error: --model-name required for list action
#
#  Model listing failed, but registration may have succeeded
#
#  Model Training & Registry Pipeline Progress: [] 100.0%
#  Step 4/4: Completed
# ------------------------------------------------------------
#
#  Model Training & Registry Pipeline completed successfully!
#
#  RESULTS:
#    •  Model Version: v20250623_160021
#    •  Artifacts saved in: models/
#    •  Registered to SageMaker Model Registry
#
#  NEXT STEPS:
#    1.  Deploy to development: Run deployment pipeline
#    2.  Test endpoint functionality
#    3.  Monitor model performance
#    4.  Promote to staging when ready
#
#  Phase 3: Fast Testing
#
#  STARTING: Testing & Quality Assurance Pipeline
# ======================================================================
#
#  Testing & Quality Assurance Pipeline Progress: [] 33.3%
#  Step 1/3: Code Formatting
# ------------------------------------------------------------
#
#  EXECUTING: Black Code Formatting
#  Description: Check code formatting with Black
#  Started at: 2025-06-23 16:02:21
# ------------------------------------------------------------
#  Black Code Formatting failed with exception: [Errno 2] No such file or directory: 'black'
#  Execution time: 0.00 seconds
#  Code formatting issues found. Running auto-format...
#
#  EXECUTING: Auto-format with Black
#  Description: Auto-format code with Black
#  Started at: 2025-06-23 16:02:21
# ------------------------------------------------------------
#  Auto-format with Black failed with exception: [Errno 2] No such file or directory: 'black'
#  Execution time: 0.00 seconds
#
#  EXECUTING: Import Sorting
#  Description: Check import sorting with isort
#  Started at: 2025-06-23 16:02:21
# ------------------------------------------------------------
#  Import Sorting failed with return code 1
#  Execution time: 0.23 seconds
#  Error output:
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/data_processing/data_validation.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/data_processing/feature_engineering.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/data_processing/feature_store_integration.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/training/train_model.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/deployment/deployment_verification.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/deployment/model_registry.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/deployment/sagemaker_deploy.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/inference/api.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/inference/predictor.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/monitoring/drift_detector.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/monitoring/performance_monitor.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/src/utils/test_data_generator.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/tests/conftest.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/tests/unit/test_data_processing.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/tests/unit/test_deployment.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/tests/unit/test_model_training.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/tests/unit/test_monitoring.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/tests/integration/test_data_pipeline.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/tests/integration/test_deployment_pipeline.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/tests/integration/test_end_to_end.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/tests/integration/test_training_pipeline.py Imports are incorrectly sorted and/or formatted.
# ERROR: /home/sagemaker-user/demand-stock-forecasting-mlops/tests/.ipynb_checkpoints/conftest-checkpoint.py Imports are incorrectly sorted and/or formatted.
#
#
#  Testing & Quality Assurance Pipeline Progress: [] 66.7%
#  Step 2/3: Code Linting
# ------------------------------------------------------------
#
#  EXECUTING: Flake8 Linting
#  Description: Check code quality with Flake8
#  Started at: 2025-06-23 16:02:21
# ------------------------------------------------------------
#  Flake8 Linting failed with return code 1
#  Execution time: 0.30 seconds
#  Standard output:
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:15:1: F401 'pathlib.Path' imported but unused
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:16:1: F401 'typing.List' imported but unused
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:16:1: F401 'typing.Tuple' imported but unused
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:53:28: E128 continuation line under-indented for visual indent
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:231:31: E128 continuation line under-indented for visual indent
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:266:101: E501 line too long (104 > 100 characters)
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:309:101: E501 line too long (107 > 100 characters)
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:321:65: W504 line break after binary operator
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:322:32: E128 continuation line under-indented for visual indent
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:354:9: F841 local variable 'e' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:444:67: W504 line break after binary operator
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:488:21: E226 missing whitespace around arithmetic operator
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:490:14: E226 missing whitespace around arithmetic operator
# src/data_processing/.ipynb_checkpoints/data_validation-checkpoint.py:505:11: W292 no newline at end of file
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:13:1: F401 'datetime.datetime' imported but unused
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:71:9: F841 local variable 'e' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:83:64: W504 line break after binary operator
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:136:101: E501 line too long (101 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:173:101: E501 line too long (148 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:174:101: E501 line too long (158 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:175:101: E501 line too long (144 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:178:101: E501 line too long (148 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:179:101: E501 line too long (158 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:182:101: E501 line too long (148 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:183:101: E501 line too long (148 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:187:101: E501 line too long (102 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:213:101: E501 line too long (117 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:371:13: F841 local variable 'e' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:541:9: F841 local variable 'e' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:548:101: E501 line too long (103 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:562:21: E226 missing whitespace around arithmetic operator
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:564:14: E226 missing whitespace around arithmetic operator
# src/data_processing/.ipynb_checkpoints/feature_engineering-checkpoint.py:572:11: W292 no newline at end of file
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:15:1: F401 'datetime.timezone' imported but unused
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:16:1: F401 'typing.List' imported but unused
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:16:1: F401 'typing.Optional' imported but unused
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:19:1: F401 'numpy as np' imported but unused
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:42:101: E501 line too long (101 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:44:58: E128 continuation line under-indented for visual indent
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:131:9: F841 local variable 'e' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:184:41: E128 continuation line under-indented for visual indent
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:208:17: F841 local variable 'athena_type' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:211:17: F841 local variable 'escaped_name' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:211:101: E501 line too long (121 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:214:9: F841 local variable 'columns_ddl' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:250:9: F841 local variable 'e' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:269:17: F841 local variable 'error_msg' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:269:101: E501 line too long (106 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:292:13: F841 local variable 'e' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:347:21: F841 local variable 'data_prefix' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:358:17: F841 local variable 'e' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:445:9: F841 local variable 'e' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:498:17: F841 local variable 'e' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:505:101: E501 line too long (108 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:525:17: F841 local variable 'e' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:550:101: E501 line too long (109 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:557:101: E501 line too long (108 > 100 characters)
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:673:21: E226 missing whitespace around arithmetic operator
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:675:14: E226 missing whitespace around arithmetic operator
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:678:9: F841 local variable 'fs_results' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:695:17: F841 local variable 'status_icon' is assigned to but never used
# src/data_processing/.ipynb_checkpoints/feature_store_integration-checkpoint.py:715:11: W292 no newline at end of file
# src/data_processing/data_validation.py:15:1: F401 'pathlib.Path' imported but unused
# src/data_processing/data_validation.py:16:1: F401 'typing.List' imported but unused
# src/data_processing/data_validation.py:16:1: F401 'typing.Tuple' imported but unused
# src/data_processing/data_validation.py:32:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:37:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:39:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:47:46: W291 trailing whitespace
# src/data_processing/data_validation.py:52:81: W291 trailing whitespace
# src/data_processing/data_validation.py:53:28: E128 continuation line under-indented for visual indent
# src/data_processing/data_validation.py:85:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:87:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:92:48: W291 trailing whitespace
# src/data_processing/data_validation.py:96:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:102:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:107:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:113:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:122:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:126:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:129:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:133:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:145:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:148:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:159:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:167:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:179:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:190:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:193:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:208:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:219:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:228:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:230:57: W291 trailing whitespace
# src/data_processing/data_validation.py:231:31: E128 continuation line under-indented for visual indent
# src/data_processing/data_validation.py:241:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:245:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:251:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:255:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:259:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:264:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:266:101: E501 line too long (104 > 100 characters)
# src/data_processing/data_validation.py:268:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:274:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:280:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:287:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:294:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:299:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:305:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:309:101: E501 line too long (107 > 100 characters)
# src/data_processing/data_validation.py:312:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:317:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:321:65: W504 line break after binary operator
# src/data_processing/data_validation.py:321:66: W291 trailing whitespace
# src/data_processing/data_validation.py:322:32: E128 continuation line under-indented for visual indent
# src/data_processing/data_validation.py:323:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:330:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:335:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:341:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:348:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:353:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:356:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:362:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:371:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:376:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:384:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:388:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:395:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:398:40: W291 trailing whitespace
# src/data_processing/data_validation.py:402:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:408:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:414:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:416:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:423:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:428:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:432:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:437:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:441:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:444:67: W504 line break after binary operator
# src/data_processing/data_validation.py:447:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:453:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:456:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:461:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:464:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:468:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:478:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:480:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:483:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:486:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:488:21: E226 missing whitespace around arithmetic operator
# src/data_processing/data_validation.py:490:14: E226 missing whitespace around arithmetic operator
# src/data_processing/data_validation.py:494:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:499:1: W293 blank line contains whitespace
# src/data_processing/data_validation.py:505:11: W292 no newline at end of file
# src/data_processing/feature_engineering.py:13:1: F401 'datetime.datetime' imported but unused
# src/data_processing/feature_engineering.py:30:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:39:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:41:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:48:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:56:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:64:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:70:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:74:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:80:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:83:64: W504 line break after binary operator
# src/data_processing/feature_engineering.py:83:65: W291 trailing whitespace
# src/data_processing/feature_engineering.py:86:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:88:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:95:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:101:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:104:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:110:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:117:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:126:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:134:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:136:101: E501 line too long (101 > 100 characters)
# src/data_processing/feature_engineering.py:138:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:143:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:147:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:153:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:156:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:161:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:167:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:170:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:173:101: E501 line too long (149 > 100 characters)
# src/data_processing/feature_engineering.py:174:101: E501 line too long (159 > 100 characters)
# src/data_processing/feature_engineering.py:175:101: E501 line too long (145 > 100 characters)
# src/data_processing/feature_engineering.py:176:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:178:101: E501 line too long (149 > 100 characters)
# src/data_processing/feature_engineering.py:179:101: E501 line too long (159 > 100 characters)
# src/data_processing/feature_engineering.py:180:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:182:101: E501 line too long (149 > 100 characters)
# src/data_processing/feature_engineering.py:183:101: E501 line too long (149 > 100 characters)
# src/data_processing/feature_engineering.py:184:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:187:101: E501 line too long (102 > 100 characters)
# src/data_processing/feature_engineering.py:190:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:197:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:202:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:206:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:210:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:213:101: E501 line too long (117 > 100 characters)
# src/data_processing/feature_engineering.py:214:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:220:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:227:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:234:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:239:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:242:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:247:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:251:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:256:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:262:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:269:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:278:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:282:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:289:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:295:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:299:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:305:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:310:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:316:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:320:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:324:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:332:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:339:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:343:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:346:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:355:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:364:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:374:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:380:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:390:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:397:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:403:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:411:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:419:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:425:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:429:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:432:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:435:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:438:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:442:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:446:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:450:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:454:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:457:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:460:1: W293 blank line contains whitespace
# src/data_processing/feature_engineering.py:463:1: W293 blank line contains whitespace
# ...
# src/training/train_model.py:310:1: W293 blank line contains whitespace
# src/training/train_model.py:318:1: W293 blank line contains whitespace
# src/training/train_model.py:329:1: W293 blank line contains whitespace
# src/training/train_model.py:332:1: W293 blank line contains whitespace
# src/training/train_model.py:336:21: E128 continuation line under-indented for visual indent
# src/training/train_model.py:340:1: W293 blank line contains whitespace
# src/training/train_model.py:346:34: W291 trailing whitespace
# src/training/train_model.py:353:29: W291 trailing whitespace
# src/training/train_model.py:358:1: W293 blank line contains whitespace
# src/training/train_model.py:360:1: W293 blank line contains whitespace
# src/training/train_model.py:365:1: W293 blank line contains whitespace
# src/training/train_model.py:372:1: W293 blank line contains whitespace
# src/training/train_model.py:375:1: W293 blank line contains whitespace
# src/training/train_model.py:379:1: W293 blank line contains whitespace
# src/training/train_model.py:385:1: W293 blank line contains whitespace
# src/training/train_model.py:389:1: W293 blank line contains whitespace
# src/training/train_model.py:391:1: W293 blank line contains whitespace
# src/training/train_model.py:395:1: W293 blank line contains whitespace
# src/training/train_model.py:398:1: W293 blank line contains whitespace
# src/training/train_model.py:407:1: W293 blank line contains whitespace
# src/training/train_model.py:414:1: W293 blank line contains whitespace
# src/training/train_model.py:418:1: W293 blank line contains whitespace
# src/training/train_model.py:423:1: W293 blank line contains whitespace
# src/training/train_model.py:428:26: E128 continuation line under-indented for visual indent
# src/training/train_model.py:430:1: W293 blank line contains whitespace
# src/training/train_model.py:434:1: W293 blank line contains whitespace
# src/training/train_model.py:438:1: W293 blank line contains whitespace
# src/training/train_model.py:446:1: W293 blank line contains whitespace
# src/training/train_model.py:455:1: W293 blank line contains whitespace
# src/training/train_model.py:462:1: W293 blank line contains whitespace
# src/training/train_model.py:464:1: W293 blank line contains whitespace
# src/training/train_model.py:469:1: W293 blank line contains whitespace
# src/training/train_model.py:472:1: W293 blank line contains whitespace
# src/training/train_model.py:475:1: W293 blank line contains whitespace
# src/training/train_model.py:484:1: W293 blank line contains whitespace
# src/training/train_model.py:488:1: W293 blank line contains whitespace
# src/training/train_model.py:495:1: W293 blank line contains whitespace
# src/training/train_model.py:498:1: W293 blank line contains whitespace
# src/training/train_model.py:504:1: W293 blank line contains whitespace
# src/training/train_model.py:508:1: W293 blank line contains whitespace
# src/training/train_model.py:513:1: W293 blank line contains whitespace
# src/training/train_model.py:517:79: W291 trailing whitespace
# src/training/train_model.py:518:28: E128 continuation line under-indented for visual indent
# src/training/train_model.py:522:1: W293 blank line contains whitespace
# src/training/train_model.py:524:1: W293 blank line contains whitespace
# src/training/train_model.py:528:1: W293 blank line contains whitespace
# src/training/train_model.py:537:1: W293 blank line contains whitespace
# src/training/train_model.py:544:101: E501 line too long (104 > 100 characters)
# src/training/train_model.py:546:1: W293 blank line contains whitespace
# src/training/train_model.py:551:1: W293 blank line contains whitespace
# src/training/train_model.py:555:1: W293 blank line contains whitespace
# src/training/train_model.py:558:1: W293 blank line contains whitespace
# src/training/train_model.py:563:1: W293 blank line contains whitespace
# src/training/train_model.py:568:1: W293 blank line contains whitespace
# src/training/train_model.py:569:101: E501 line too long (114 > 100 characters)
# src/training/train_model.py:570:1: W293 blank line contains whitespace
# src/training/train_model.py:579:101: E501 line too long (104 > 100 characters)
# src/training/train_model.py:582:1: W293 blank line contains whitespace
# src/training/train_model.py:588:1: W293 blank line contains whitespace
# src/training/train_model.py:602:1: W293 blank line contains whitespace
# src/training/train_model.py:608:1: W293 blank line contains whitespace
# src/training/train_model.py:612:70: W291 trailing whitespace
# src/training/train_model.py:613:29: E128 continuation line under-indented for visual indent
# src/training/train_model.py:615:32: E226 missing whitespace around arithmetic operator
# src/training/train_model.py:617:32: E226 missing whitespace around arithmetic operator
# src/training/train_model.py:618:1: W293 blank line contains whitespace
# src/training/train_model.py:628:1: W293 blank line contains whitespace
# src/training/train_model.py:633:1: W293 blank line contains whitespace
# src/training/train_model.py:636:1: W293 blank line contains whitespace
# src/training/train_model.py:641:1: W293 blank line contains whitespace
# src/training/train_model.py:647:1: W293 blank line contains whitespace
# src/training/train_model.py:650:1: W293 blank line contains whitespace
# src/training/train_model.py:654:1: W293 blank line contains whitespace
# src/training/train_model.py:658:1: W293 blank line contains whitespace
# src/training/train_model.py:674:1: W293 blank line contains whitespace
# src/training/train_model.py:679:1: W293 blank line contains whitespace
# src/training/train_model.py:686:1: W293 blank line contains whitespace
# src/training/train_model.py:689:101: E501 line too long (101 > 100 characters)
# src/training/train_model.py:691:101: E501 line too long (103 > 100 characters)
# src/training/train_model.py:692:1: W293 blank line contains whitespace
# src/training/train_model.py:699:1: W293 blank line contains whitespace
# src/training/train_model.py:700:36: E226 missing whitespace around arithmetic operator
# src/training/train_model.py:702:36: E226 missing whitespace around arithmetic operator
# src/training/train_model.py:703:1: W293 blank line contains whitespace
# src/training/train_model.py:709:1: W293 blank line contains whitespace
# src/training/train_model.py:721:1: W293 blank line contains whitespace
# src/training/train_model.py:723:1: W293 blank line contains whitespace
# src/training/train_model.py:726:1: W293 blank line contains whitespace
# src/training/train_model.py:730:1: W293 blank line contains whitespace
# src/training/train_model.py:733:1: W293 blank line contains whitespace
# src/training/train_model.py:736:28: W291 trailing whitespace
# src/training/train_model.py:737:30: W291 trailing whitespace
# src/training/train_model.py:740:1: W293 blank line contains whitespace
# src/training/train_model.py:742:25: E226 missing whitespace around arithmetic operator
# src/training/train_model.py:744:18: E226 missing whitespace around arithmetic operator
# src/training/train_model.py:749:1: W293 blank line contains whitespace
# src/training/train_model.py:751:19: F541 f-string is missing placeholders
# src/training/train_model.py:759:1: W293 blank line contains whitespace
# src/training/train_model.py:762:1: W293 blank line contains whitespace
# src/training/train_model.py:763:27: E226 missing whitespace around arithmetic operator
# src/training/train_model.py:765:27: E226 missing whitespace around arithmetic operator
# src/training/train_model.py:766:1: W293 blank line contains whitespace
# src/training/train_model.py:771:15: F541 f-string is missing placeholders
# src/training/train_model.py:776:11: W292 no newline at end of file
# src/utils/test_data_generator.py:11:1: F401 'pandas as pd' imported but unused
# src/utils/test_data_generator.py:13:1: F401 'datetime.timedelta' imported but unused
# src/utils/test_data_generator.py:20:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:26:72: W291 trailing whitespace
# src/utils/test_data_generator.py:29:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:54:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:57:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:65:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:87:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:95:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:117:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:125:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:147:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:155:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:177:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:185:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:207:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:215:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:237:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:245:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:267:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:275:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:279:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:289:101: E501 line too long (112 > 100 characters)
# src/utils/test_data_generator.py:301:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:303:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:307:69: W291 trailing whitespace
# src/utils/test_data_generator.py:310:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:312:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:316:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:325:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:327:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:331:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:371:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:378:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:382:47: E226 missing whitespace around arithmetic operator
# src/utils/test_data_generator.py:387:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:390:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:391:15: F541 f-string is missing placeholders
# src/utils/test_data_generator.py:394:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:396:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:415:67: W291 trailing whitespace
# src/utils/test_data_generator.py:421:101: E501 line too long (102 > 100 characters)
# src/utils/test_data_generator.py:424:101: E501 line too long (219 > 100 characters)
# src/utils/test_data_generator.py:426:101: E501 line too long (170 > 100 characters)
# src/utils/test_data_generator.py:427:101: E501 line too long (170 > 100 characters)
# src/utils/test_data_generator.py:428:101: E501 line too long (179 > 100 characters)
# src/utils/test_data_generator.py:430:101: E501 line too long (144 > 100 characters)
# src/utils/test_data_generator.py:433:101: E501 line too long (165 > 100 characters)
# src/utils/test_data_generator.py:434:101: E501 line too long (218 > 100 characters)
# src/utils/test_data_generator.py:437:101: E501 line too long (122 > 100 characters)
# src/utils/test_data_generator.py:439:101: E501 line too long (102 > 100 characters)
# src/utils/test_data_generator.py:443:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:447:15: F541 f-string is missing placeholders
# src/utils/test_data_generator.py:448:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:474:101: E501 line too long (138 > 100 characters)
# src/utils/test_data_generator.py:477:101: E501 line too long (138 > 100 characters)
# src/utils/test_data_generator.py:480:101: E501 line too long (148 > 100 characters)
# src/utils/test_data_generator.py:489:101: E501 line too long (131 > 100 characters)
# src/utils/test_data_generator.py:491:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:495:15: F541 f-string is missing placeholders
# src/utils/test_data_generator.py:507:101: E501 line too long (101 > 100 characters)
# src/utils/test_data_generator.py:511:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:512:64: W291 trailing whitespace
# src/utils/test_data_generator.py:513:24: E128 continuation line under-indented for visual indent
# src/utils/test_data_generator.py:514:38: W291 trailing whitespace
# src/utils/test_data_generator.py:515:24: E128 continuation line under-indented for visual indent
# src/utils/test_data_generator.py:515:96: W291 trailing whitespace
# src/utils/test_data_generator.py:516:32: E128 continuation line under-indented for visual indent
# src/utils/test_data_generator.py:516:98: W291 trailing whitespace
# src/utils/test_data_generator.py:517:32: E128 continuation line under-indented for visual indent
# src/utils/test_data_generator.py:518:24: E128 continuation line under-indented for visual indent
# src/utils/test_data_generator.py:519:61: W291 trailing whitespace
# src/utils/test_data_generator.py:520:24: E128 continuation line under-indented for visual indent
# src/utils/test_data_generator.py:522:24: E128 continuation line under-indented for visual indent
# src/utils/test_data_generator.py:523:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:525:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:528:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:530:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:535:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:536:15: F541 f-string is missing placeholders
# src/utils/test_data_generator.py:537:101: E501 line too long (156 > 100 characters)
# src/utils/test_data_generator.py:538:101: E501 line too long (156 > 100 characters)
# src/utils/test_data_generator.py:539:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:544:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:554:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:558:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:560:15: F541 f-string is missing placeholders
# src/utils/test_data_generator.py:561:101: E501 line too long (138 > 100 characters)
# src/utils/test_data_generator.py:562:1: W293 blank line contains whitespace
# src/utils/test_data_generator.py:563:11: F541 f-string is missing placeholders
# src/utils/test_data_generator.py:567:11: W292 no newline at end of file
#
#
#  EXECUTING: MyPy Type Checking
#  Description: Static type checking with MyPy
#  Started at: 2025-06-23 16:02:21
# ------------------------------------------------------------
#  MyPy Type Checking failed with exception: [Errno 2] No such file or directory: 'mypy'
#  Execution time: 0.00 seconds
#  MyPy type checking found issues (non-blocking)
#
#  Testing & Quality Assurance Pipeline Progress: [] 100.0%
#  Step 3/3: Test Execution
# ------------------------------------------------------------
#
#  EXECUTING: Pytest
#  Description: Run unit and integration tests
#  Started at: 2025-06-23 16:02:21
# ------------------------------------------------------------
#  Pytest failed with return code 4
#  Execution time: 1.40 seconds
#  Error output:
# ImportError while loading conftest '/home/sagemaker-user/demand-stock-forecasting-mlops/tests/conftest.py'.
# tests/conftest.py:22: in <module>
#     from moto import mock_s3, mock_sagemaker, mock_athena
# E   ModuleNotFoundError: No module named 'moto'
#
#  Test execution failed. Check test output for details.
#  Development workflow failed at testing
#
#  Master workflow execution failed. Check logs for details.

# %% [markdown]
# ##  11. Project Summary & Next Steps
#
# **Purpose**: Provide a comprehensive summary of the MLOps pipeline execution and guide next steps.
#
# This final section summarizes:
# -  Completed pipeline components
# -  Active endpoints and services
# -  Available dashboards and monitoring
# -  Recommended next steps
# -  Troubleshooting guidance
#
# ---

# %%
def generate_project_summary():
    """
    Generate comprehensive project summary and status
    """
    print("\n MLOPS PROJECT SUMMARY")
    print("=" * 70)
    
    # Project Information
    print(f"\n PROJECT INFORMATION:")
    print(f"   •  Project: Demand Stock Forecasting MLOps")
    print(f"   •  Author: Bhupal Lambodhar")
    print(f"   •  Email: btiduwarlambodhar@sandiego.edu")
    print(f"   •  Repository: https://github.com/btlambodh/demand-stock-forecasting-mlops")
    print(f"   •  Report Generated: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    
    # Check system status
    print(f"\n SYSTEM STATUS:")
    
    # Check data files
    data_path = PROJECT_ROOT / 'data'
    models_path = PROJECT_ROOT / 'models'
    
    if data_path.exists():
        data_files = list(data_path.rglob('*.csv')) + list(data_path.rglob('*.parquet'))
        print(f"   •  Data Files: {len(data_files)} found")
    else:
        print(f"   •  Data Files:  No data directory")
    
    if models_path.exists():
        model_files = list(models_path.rglob('*.pkl')) + list(models_path.rglob('*.joblib'))
        print(f"   •  Model Files: {len(model_files)} found")
        
        # Check for best model
        best_model = models_path / 'best_model.pkl'
        if best_model.exists():
            print(f"   •  Best Model:  Available")
        else:
            print(f"   •  Best Model:  Not found")
    else:
        print(f"   •  Model Files:  No models directory")
    
    # Check SageMaker endpoints
    try:
        sagemaker_client = boto3.client('sagemaker', region_name=config['aws']['region'])
        endpoints = sagemaker_client.list_endpoints()['Endpoints']
        
        active_endpoints = [ep for ep in endpoints if ep['EndpointStatus'] == 'InService']
        print(f"   •  SageMaker Endpoints: {len(active_endpoints)} active")
        
        for endpoint in active_endpoints:
            print(f"     - {endpoint['EndpointName']}: {endpoint['EndpointStatus']}")
            
    except Exception as e:
        print(f"   •  SageMaker Endpoints:  Cannot check ({e})")
    
    # Check monitoring status
    print(f"\n MONITORING STATUS:")
    monitoring_active = check_monitoring_status()
    
    if monitoring_active:
        print(f"   •  Monitoring Services:  Active")
    else:
        print(f"   •  Monitoring Services:  Not running")
    
    # Check available dashboards
    ports_to_check = [8050, 8051, 8052]
    active_dashboards = []
    
    for port in ports_to_check:
        with closing(socket.socket(socket.AF_INET, socket.SOCK_STREAM)) as sock:
            if sock.connect_ex(('localhost', port)) == 0:
                active_dashboards.append(f"http://localhost:{port}")
    
    if active_dashboards:
        print(f"   •  Active Dashboards:")
        for dashboard in active_dashboards:
            print(f"     - {dashboard}")
    else:
        print(f"   •  Dashboards:  None active")
    
    # Next steps recommendations
    print(f"\n RECOMMENDED NEXT STEPS:")
    
    if not data_path.exists() or len(list(data_path.rglob('*.csv'))) == 0:
        print(f"   1.  Add training data to data/raw/ directory")
        print(f"   2.  Run data pipeline to process features")
    elif not models_path.exists() or not (models_path / 'best_model.pkl').exists():
        print(f"   1.  Run training pipeline to create models")
        print(f"   2.  Validate model performance")
    else:
        print(f"   1.  Deploy models to different environments")
        print(f"   2.  Monitor model performance in production")
        print(f"   3.  Set up automated retraining")
        print(f"   4.  Analyze business impact")
    
    # Troubleshooting guide
    print(f"\n TROUBLESHOOTING GUIDE:")
    print(f"   •  Data Issues: Check data/raw/ for input files")
    print(f"   •  Model Issues: Review models/ directory and logs")
    print(f"   •  AWS Issues: Verify credentials and permissions")
    print(f"   •  Monitoring Issues: Check port availability and processes")
    print(f"   •  Test Failures: Review test output and fix issues")
    
    # Useful commands
    print(f"\n USEFUL COMMANDS:")
    print(f"   • Status check: Run health check cells above")
    print(f"   • Stop services: Set stop_all_services=True and run")
    print(f"   • View logs: Check data/monitoring/logs/ directory")
    print(f"   • AWS Console: Check SageMaker endpoints and Model Registry")
    
    print(f"\n MLOps Pipeline Report Complete!")
    print(f" Support: btiduwarlambodhar@sandiego.edu")

# Generate the summary
generate_project_summary()
# Out:
#  MLOPS PROJECT SUMMARY
# ======================================================================
#
#  PROJECT INFORMATION:
#    •  Project: Demand Stock Forecasting MLOps
#    •  Author: Bhupal Lambodhar
#    •  Email: btiduwarlambodhar@sandiego.edu
#    •  Repository: https://github.com/btlambodh/demand-stock-forecasting-mlops
#    •  Report Generated: 2025-06-23 16:09:54
#
#  SYSTEM STATUS:
#    •  Data Files: 8 found
#    •  Model Files: 6 found
#    •  Best Model:  Available
#    •  SageMaker Endpoints: 1 active
#      - produce-forecast-dev: InService
#
#  MONITORING STATUS:
#
#  MONITORING SYSTEM STATUS
# ==================================================
#  Found 3 monitoring processes:
#    • Performance: PID 25539
#    • Drift Detection: PID 25542
#    • Performance: PID 25610
#
#  Port Status:
#    • Port 8002: ⚪ Available
#    • Port 8050:  In Use
#    • Port 8051: ⚪ Available
#    • Port 8052: ⚪ Available
#    •  Monitoring Services:  Active
#    •  Active Dashboards:
#      - http://localhost:8050
#
#  RECOMMENDED NEXT STEPS:
#    1.  Deploy models to different environments
#    2.  Monitor model performance in production
#    3.  Set up automated retraining
#    4.  Analyze business impact
#
#  TROUBLESHOOTING GUIDE:
#    •  Data Issues: Check data/raw/ for input files
#    •  Model Issues: Review models/ directory and logs
#    •  AWS Issues: Verify credentials and permissions
#    •  Monitoring Issues: Check port availability and processes
#    •  Test Failures: Review test output and fix issues
#
#  USEFUL COMMANDS:
#    • Status check: Run health check cells above
#    • Stop services: Set stop_all_services=True and run
#    • View logs: Check data/monitoring/logs/ directory
#    • AWS Console: Check SageMaker endpoints and Model Registry
#
#  MLOps Pipeline Report Complete!
#  Support: btiduwarlambodhar@sandiego.edu

# %% [markdown]
# ---
#
# ##  Congratulations!
#
# You have successfully set up and executed the **Demand Stock Forecasting MLOps Pipeline**!
#
# ###  A Complete ML-Ops Process Accomplished:
#
#  **Complete Data Pipeline** with validation and feature engineering
#  **Model Training & Registry** with automated versioning
#  **Multi-Environment Deployment** (dev/staging/production)
#  **Real-time Monitoring** with drift detection
#  **Quality Assurance** with comprehensive testing
#  **AWS Integration** with SageMaker, S3, and Athena
#
# ###  Resources:
#
# - **Project Repository**: https://github.com/btlambodh/demand-stock-forecasting-mlops
# - **Author**: Bhupal Lambodhar (btiduwarlambodhar@sandiego.edu)
# - **Institution**: University of San Diego
#
# ###  Keep Building!
#
# This notebook provides a solid foundation for MLOps workflows. Continue enhancing with:
# - Advanced model architectures
# - Real-time feature engineering
# - A/B testing capabilities
# - Advanced monitoring and alerting
# - Automated model retraining
#
# ---
#
# *Happy MLOps!*
